# %%
import numpy as np
import pandas as pd
data = pd.read_csv("/Users/nidhishgupta/Desktop/Dream11_Fantasy Team_Predictor/data/processed/full_req_data.csv")

# %%
data.columns
pd.set_option("display.max_columns",None)

# %%
import joblib

model = joblib.load("/Users/nidhishgupta/Desktop/Dream11_Fantasy Team_Predictor/models/point_predicter.pkl")

# %%
team1 = "Chennai Super Kings"
team2 = "Mumbai Indians"

venue = "Wankhede Stadium"
team1_squad =  [
    'MS Dhoni','Ravindra Jadeja','Ruturaj Gaikwad','Deepak Chahar','Moeen Ali',
'Shivam Dube','Matheesha Pathirana','Ajinkya Rahane','Daryl Mitchell',
'Mitchell Santner','Tushar Deshpande'
]
team2_squad = ['Rohit Sharma','Ishan Kishan','Suryakumar Yadav','Hardik Pandya',
'Tim David','Jasprit Bumrah','Piyush Chawla','Tilak Varma',
'Gerald Coetzee','Romario Shepherd','Nehal Wadhera'
]
squad = team1_squad+team2_squad

# %%
historical_data = pd.read_csv("/Users/nidhishgupta/Desktop/Dream11_Fantasy Team_Predictor/data/processed/historical_data.csv")
historical_data['pitch_type'] = historical_data['pitch_type'].fillna('balanced')

# %%
player_mapping = {
    'A Ashish Reddy': 'Ashish Reddy',
    'A Badoni': 'Ayush Badoni',
    'A Chandila': 'Ajit Chandila',
    'A Chopra': 'Aakash Chopra',
    'A Choudhary': 'Aniket Choudhary',
    'A Dananjaya': 'Akila Dananjaya',
    'A Flintoff': 'Andrew Flintoff',
    'A Kamboj': 'Anshul Kamboj',
    'A Kumble': 'Anil Kumble',
    'A Manohar': 'Abhinav Manohar',
    'A Mhatre': 'Ayush Mhatre',
    'A Mishra': 'Amit Mishra',
    'A Mithun': 'Abhimanyu Mithun',
    'A Mukund': 'Abhinav Mukund',
    'A Nehra': 'Ashish Nehra',
    'A Nel': 'André Nel',
    'A Nortje': 'Anrich Nortje',
    'A Raghuvanshi': 'Angkrish Raghuvanshi',
    'A Singh': 'Anureet Singh',
    'A Symonds': 'Andrew Symonds',
    'A Tomar': 'Anshuman Tomar',
    'A Uniyal': 'Amit Uniyal',
    'A Zampa': 'Adam Zampa',
    'AA Bilakhia': 'Akshath Bilakhia',
    'AA Chavan': 'Ankeet Chavan',
    'AA Jhunjhunwala': 'Abhishek Jhunjhunwala',
    'AA Kazi': 'Abrar Kazi',
    'AA Kulkarni': 'Arshin Kulkarni',
    'AA Noffke': 'Ashley Noffke',
    'AB Agarkar': 'Ajit Agarkar',
    'AB Barath': 'Adrian Barath',
    'AB Dinda': 'Ashoke Dinda',
    'AB McDonald': 'Andrew McDonald',
    'AB de Villiers': 'AB de Villiers',
    'AC Blizzard': 'Aiden Blizzard',
    'AC Gilchrist': 'Adam Gilchrist',
    'AC Thomas': 'Alfonso Thomas',
    'AC Voges': 'Adam Voges',
    'AD Hales': 'Alex Hales',
    'AD Mascarenhas': 'Dimitri Mascarenhas',
    'AD Mathews': 'Angelo Mathews',
    'AD Nath': 'Akshdeep Nath',
    'AD Russell': 'Andre Russell',
    'AF Milne': 'Adam Milne',
    'AG Murtaza': 'Ali Murtaza',
    'AG Paunikar': 'Amit Paunikar',
    'AJ Finch': 'Aaron Finch',
    'AJ Hosein': 'Akeal Hosein',
    'AJ Turner': 'Ashton Turner',
    'AJ Tye': 'Andrew Tye',
    'AK Markram': 'Aiden Markram',
    'AL Menaria': 'Ashok Menaria',
    'AM Nayar': 'Abhishek Nayar',
    'AM Rahane': 'Ajinkya Rahane',
    'AM Salvi': 'Aavishkar Salvi',
    'AN Ahmed': 'Abu Nechim',
    'AN Ghosh': 'Arindam Ghosh',
    'AP Dole': 'Aditya Dole',
    'AP Majumdar': 'Anustup Majumdar',
    'AP Tare': 'Aditya Tare',
    'AR Bawne': 'Ankit Bawne',
    'AR Patel': 'Axar Patel',
    'AS Joseph': 'Alzarri Joseph',
    'AS Rajpoot': 'Ankit Rajpoot',
    'AS Raut': 'Abhishek Raut',
    'AS Roy': 'Anukul Roy',
    'AS Yadav': 'Suryakumar Yadav',
    'AT Carey': 'Alex Carey',
    'AT Rayudu': 'Ambati Rayudu',
    'AU Rashid': 'Adil Rashid',
    'AUK Pathan': 'Asad Pathan',
    'B Akhil': 'Balachandra Akhil',
    'B Chipli': 'Bharat Chipli',
    'B Geeves': 'Brett Geeves',
    'B Indrajith': 'Baba Indrajith',
    'B Kumar': 'Bhuvaneshwar Kumar',
    'B Laughlin': 'Ben Laughlin',
    'B Lee': 'Brett Lee',
    'B Sai Sudharsan': 'Sai Sudharsan',
    'B Stanlake': 'Billy Stanlake',
    'B Sumanth': 'Bodanapu Sumanth',
    'BA Bhatt': 'Bhargav Bhatt',
    'BA Stokes': 'Ben Stokes',
    'BAW Mendis': 'Ajantha Mendis',
    'BB McCullum': 'Brendon McCullum',
    'BB Samantray': 'Biplab Samantray',
    'BB Sran': 'Barinder Sran',
    'BCJ Cutting': 'Ben Cutting',
    'BE Hendricks': 'Beuran Hendricks',
    'BJ Haddin': 'Brad Haddin',
    'BJ Hodge': 'Brad Hodge',
    'BJ Rohrer': 'Ben Rohrer',
    'BKG Mendis': 'Jeevan Mendis',
    'BMAJ Mendis': 'Jeevan Mendis',
    'BR Dunk': 'Ben Dunk',
    'BR Sharath': 'Barafe Sharath',
    'BW Hilfenhaus': 'Ben Hilfenhaus',
    'C Bosch': 'Corbin Bosch',
    'C Ganapathy': 'Chandrasekar Ganapathy',
    'C Green': 'Cameron Green',
    'C Madan': 'Chandan Madan',
    'C Munro': 'Colin Munro',
    'C Nanda': 'Chetan Nanda',
    'C Sakariya': 'Chetan Sakariya',
    'C de Grandhomme': 'Colin de Grandhomme',
    'CA Ingram': 'Colin Ingram',
    'CA Lynn': 'Chris Lynn',
    'CA Pujara': 'Cheteshwar Pujara',
    'CH Gayle': 'Chris Gayle',
    'CH Morris': 'Chris Morris',
    'CJ Anderson': 'Corey Anderson',
    'CJ Dala': 'Junior Dala',
    'CJ Ferguson': 'Callum Ferguson',
    'CJ Green': 'Chris Green',
    'CJ Jordan': 'Chris Jordan',
    'CJ McKay': 'Clint McKay',
    'CK Kapugedera': 'Chamara Kapugedera',
    'CK Langeveldt': 'Charl Langeveldt',
    'CL White': 'Cameron White',
    'CM Gautam': 'C. M. Gautam',
    'CR Brathwaite': 'Carlos Brathwaite',
    'CR Woakes': 'Chris Woakes',
    'CRD Fernando': 'Dilhara Fernando',
    'CV Varun': 'Varun Chakravarthy',
    'D Brevis': 'Dewald Brevis',
    'D Ferreira': 'Donovan Ferreira',
    'D Jansen': 'Duan Jansen',
    'D Kalyankrishna': 'Doddapaneni Kalyankrishna',
    'D Padikkal': 'Devdutt Padikkal',
    'D Pretorius': 'Dwaine Pretorius',
    'D Salunkhe': 'Dinesh Salunkhe',
    'D Wiese': 'David Wiese',
    'D du Preez': 'Dillon du Preez',
    'DA Miller': 'David Miller',
    'DA Warner': 'David Warner',
    'DAJ Bracewell': 'Doug Bracewell',
    'DB Das': 'Debabrata Das',
    'DB Ravi Teja': 'Dwaraka Ravi Teja',
    'DE Bollinger': 'Doug Bollinger',
    'DG Nalkande': 'Darshan Nalkande',
    'DH Yagnik': 'Dishant Yagnik',
    'DJ Bravo': 'Dwayne Bravo',
    'DJ Harris': 'Daniel Harris',
    'DJ Hooda': 'Deepak Hooda',
    'DJ Hussey': 'David Hussey',
    'DJ Jacobs': 'Davy Jacobs',
    'DJ Malan': 'Dawid Malan',
    'DJ Mitchell': 'Daryl Mitchell',
    'DJ Muthuswami': 'Domnic Muthuswami',
    'DJ Thornely': 'Dominic Thornely',
    'DJ Willey': 'David Willey',
    'DJG Sammy': 'Darren Sammy',
    'DJM Short': "D'Arcy Short",
    'DL Chahar': 'Deepak Chahar',
    'DL Vettori': 'Daniel Vettori',
    'DM Bravo': 'Darren Bravo',
    'DNT Zoysa': 'Nuwan Zoysa',
    'DP Conway': 'Devon Conway',
    'DP Nannes': 'Dirk Nannes',
    'DP Vijaykumar': 'Doddapaneni Vijaykumar',
    'DPMD Jayawardene': 'Mahela Jayawardene',
    'DR Martyn': 'Damien Martyn',
    'DR Sams': 'Daniel Sams',
    'DR Shorey': 'Dhruv Shorey',
    'DR Smith': 'Dwayne Smith',
    'DS Kulkarni': 'Dhawal Kulkarni',
    'DS Lehmann': 'Darren Lehmann',
    'DS Rathi': 'Dhruv Rathi',
    'DT Christian': 'Dan Christian',
    'DT Patil': 'Dinesh Patil',
    'DW Steyn': 'Dale Steyn',
    'E Lewis': 'Evin Lewis',
    'E Malinga': 'Lasith Malinga',
    'EJG Morgan': 'Eoin Morgan',
    'ER Dwivedi': 'Eklavya Dwivedi',
    'F Behardien': 'Farhaan Behardien',
    'F du Plessis': 'Faf du Plessis',
    'FA Allen': 'Fabian Allen',
    'FH Edwards': 'Fidel Edwards',
    'FY Fazal': 'Faiz Fazal',
    'G Coetzee': 'Gerald Coetzee',
    'G Gambhir': 'Gautam Gambhir',
    'GB Hogg': 'Brad Hogg',
    'GC Smith': 'Graeme Smith',
    'GC Viljoen': 'Hardus Viljoen',
    'GD McGrath': 'Glenn McGrath',
    'GD Phillips': 'Glenn Phillips',
    'GH Vihari': 'Hanuma Vihari',
    'GHS Garton': 'George Garton',
    'GJ Bailey': 'George Bailey',
    'GJ Maxwell': 'Glenn Maxwell',
    'GR Napier': 'Graham Napier',
    'GS Sandhu': 'Gurinder Sandhu',
    'H Das': 'Halhadar Das',
    'H Klaasen': 'Heinrich Klaasen',
    'H Sharma': 'Himanshu Sharma',
    'HC Brook': 'Harry Brook',
    'HE van der Dussen': 'Rassie van der Dussen',
    'HF Gurney': 'Harry Gurney',
    'HH Gibbs': 'Herschelle Gibbs',
    'HH Pandya': 'Hardik Pandya',
    'HM Amla': 'Hashim Amla',
    'HR Shokeen': 'Hrithik Shokeen',
    'HV Patel': 'Harshal Patel',
    'I Malhotra': 'Ishan Malhotra',
    'I Sharma': 'Ishant Sharma',
    'I Udana': 'Isuru Udana',
    'IC Pandey': 'Ishwar Pandey',
    'IC Porel': 'Ishan Porel',
    'IK Pathan': 'Irfan Pathan',
    'IR Jaggi': 'Ishank Jaggi',
    'IS Sodhi': 'Ish Sodhi',
    'J Arunkumar': 'Jagadeesh Arunkumar',
    'J Botha': 'Johan Botha',
    'J Fraser-McGurk': 'Jake Fraser-McGurk',
    'J Little': 'Joshua Little',
    'J Overton': 'Jamie Overton',
    'J Suchith': 'Jagadeesha Suchith',
    'J Syed Mohammad': 'Jamaluddin Syed Mohammad',
    'J Theron': 'Juan Theron',
    'J Yadav': 'Jayant Yadav',
    'JA Morkel': 'Albie Morkel',
    'JA Richardson': 'Jhye Richardson',
    'JC Archer': 'Jofra Archer',
    'JC Buttler': 'Jos Buttler',
    'JD Ryder': 'Jesse Ryder',
    'JD Unadkat': 'Jaydev Unadkat',
    'JDP Oram': 'Jacob Oram',
    'JDS Neesham': 'Jimmy Neesham',
    'JE Root': 'Joe Root',
    'JE Taylor': 'Jerome Taylor',
    'JEC Franklin': 'James Franklin',
    'JG Bethell': 'Jacob Bethell',
    'JH Kallis': 'Jacques Kallis',
    'JJ Bumrah': 'Jasprit Bumrah',
    'JJ Roy': 'Jason Roy',
    'JJ van der Wath': 'Johan van der Wath',
    'JL Denly': 'Joe Denly',
    'JL Pattinson': 'James Pattinson',
    'JM Bairstow': 'Jonny Bairstow',
    'JM Kemp': 'Justin Kemp',
    'JM Sharma': 'Jitesh Sharma',
    'JO Holder': 'Jason Holder',
    'JP Behrendorff': 'Jason Behrendorff',
    'JP Duminy': 'JP Duminy',
    'JP Faulkner': 'James Faulkner',
    'JP Inglis': 'Josh Inglis',
    'JPR Scantlebury-Searles': 'Javon Searles',
    'JR Hazlewood': 'Josh Hazlewood',
    'JR Hopes': 'James Hopes',
    'JR Philippe': 'Josh Philippe',
    'JW Hastings': 'John Hastings',
    'K Goel': 'Karan Goel',
    'K Gowtham': 'Krishnappa Gowtham',
    'K Kartikeya': 'Kumar Kartikeya',
    'K Khejroliya': 'Kulwant Khejroliya',
    'K Rabada': 'Kagiso Rabada',
    'K Santokie': 'Krishmar Santokie',
    'K Upadhyay': 'Krishnakumar Upadhyay',
    'K Yadav': 'Kuldeep Yadav',
    'KA Jamieson': 'Kyle Jamieson',
    'KA Maharaj': 'Keshav Maharaj',
    'KA Pollard': 'Kieron Pollard',
    'KAJ Roach': 'Kemar Roach',
    'KB Arun Karthik': 'Arun Karthik',
    'KC Cariappa': 'K. C. Cariappa',
    'KC Sangakkara': 'Kumar Sangakkara',
    'KD Karthik': 'Dinesh Karthik',
    'KH Pandya': 'Krunal Pandya',
    'KJ Abbott': 'Kyle Abbott',
    'KK Ahmed': 'Khaleel Ahmed',
    'KK Cooper': 'Kevon Cooper',
    'KK Nair': 'Karun Nair',
    'KL Nagarkoti': 'Kamlesh Nagarkoti',
    'KL Rahul': 'KL Rahul',
    'KM Asif': 'KM Asif',
    'KM Jadhav': 'Kedar Jadhav',
    'KMA Paul': 'Keemo Paul',
    'KMDN Kulasekara': 'Nuwan Kulasekara',
    'KP Appanna': 'Kotarangada Appanna',
    'KP Pietersen': 'Kevin Pietersen',
    'KR Mayers': 'Kyle Mayers',
    'KR Sen': 'Kuldeep Sen',
    'KS Bharat': 'Srikar Bharat',
    'KS Rathore': 'Kunal Singh Rathore',
    'KS Sharma': 'Karn Sharma',
    'KS Williamson': 'Kane Williamson',
    'KT Maphaka': 'Kwena Maphaka',
    'KV Sharma': 'Karn Sharma',
    'KW Richardson': 'Kane Richardson',
    'L Ablish': 'Love Ablish',
    'L Balaji': 'Lakshmipathy Balaji',
    'L Ngidi': 'Lungi Ngidi',
    'L Ronchi': 'Luke Ronchi',
    'L Wood': 'Luke Wood',
    'LA Carseldine': 'Lee Carseldine',
    'LA Pomersbach': 'Luke Pomersbach',
    'LB Williams': 'Lizaad Williams',
    'LE Plunkett': 'Liam Plunkett',
    'LH Ferguson': 'Lockie Ferguson',
    'LI Meriwala': 'Lukman Meriwala',
    'LJ Wright': 'Luke Wright',
    'LMP Simmons': 'Lendl Simmons',
    'LPC Silva': 'Chamara Silva',
    'LR Shukla': 'Laxmi Ratan Shukla',
    'LRPL Taylor': 'Ross Taylor',
    'LS Livingstone': 'Liam Livingstone',
    'M Ashwin': 'Murugan Ashwin',
    'M Jansen': 'Marco Jansen',
    'M Kaif': 'Mohammad Kaif',
    'M Kartik': 'Murali Kartik',
    'M Klinger': 'Michael Klinger',
    'M Manhas': 'Mithun Manhas',
    'M Markande': 'Mayank Markande',
    'M Morkel': 'Morne Morkel',
    'M Muralitharan': 'Muttiah Muralitharan',
    'M Ntini': 'Makhaya Ntini',
    'M Pathirana': 'Matheesha Pathirana',
    'M Prasidh Krishna': 'Prasidh Krishna',
    'M Rawat': 'Mahesh Rawat',
    'M Shahrukh Khan': 'Shahrukh Khan',
    'M Siddharth': 'Manimaran Siddharth',
    'M Theekshana': 'Maheesh Theekshana',
    'M Tiwari': 'Manoj Tiwary',
    'M Vijay': 'Murali Vijay',
    'M Vohra': 'Manan Vohra',
    'M de Lange': 'Marchant de Lange',
    'MA Agarwal': 'Mayank Agarwal',
    'MA Khote': 'Musavir Khote',
    'MA Starc': 'Mitchell Starc',
    'MA Wood': 'Mark Wood',
    'MB Parmar': 'Mohnish Parmar',
    'MC Henriques': 'Moises Henriques',
    'MC Juneja': 'Manpreet Juneja',
    'MD Mishra': 'Mohnish Mishra',
    'MD Shanaka': 'Dasun Shanaka',
    'MDKJ Perera': 'Kusal Perera',
    'MEK Hussey': 'Michael Hussey',
    'MF Maharoof': 'Farveez Maharoof',
    'MG Bracewell': 'Michael Bracewell',
    'MG Johnson': 'Mitchell Johnson',
    'MG Neser': 'Michael Neser',
    'MJ Clarke': 'Michael Clarke',
    'MJ Guptill': 'Martin Guptill',
    'MJ Henry': 'Matt Henry',
    'MJ Lumb': 'Michael Lumb',
    'MJ McClenaghan': 'Mitchell McClenaghan',
    'MJ Owen': 'Mitchell Owen',
    'MJ Santner': 'Mitchell Santner',
    'MJ Suthar': 'Manav Suthar',
    'MK Lomror': 'Mahipal Lomror',
    'MK Pandey': 'Manish Pandey',
    'MK Tiwary': 'Manoj Tiwary',
    'ML Hayden': 'Matthew Hayden',
    'MM Ali': 'Moeen Ali',
    'MM Patel': 'Munaf Patel',
    'MM Sharma': 'Mohit Sharma',
    'MN Samuels': 'Marlon Samuels',
    'MN van Wyk': 'Morne van Wyk',
    'MP Breetzke': 'Matthew Breetzke',
    'MP Stoinis': 'Marcus Stoinis',
    'MP Yadav': 'Mayank Yadav',
    'MR Marsh': 'Mitchell Marsh',
    'MS Bhandage': 'Manoj Bhandage',
    'MS Bisla': 'Manvinder Bisla',
    'MS Dhoni': 'MS Dhoni',
    'MS Gony': 'Manpreet Gony',
    'MS Wade': 'Matthew Wade',
    'MV Boucher': 'Mark Boucher',
    'MW Short': 'Matthew Short',
    'N Burger': 'Nandre Burger',
    'N Jagadeesan': 'Narayan Jagadeesan',
    'N Pooran': 'Nicholas Pooran',
    'N Rana': 'Nitish Rana',
    'N Saini': 'Navdeep Saini',
    'N Thushara': 'Nuwan Thushara',
    'N Wadhera': 'Nehal Wadhera',
    'NA Saini': 'Navdeep Saini',
    'NB Singh': 'Nikhil Singh',
    'ND Doshi': 'Nayan Doshi',
    'NJ Maddinson': 'Nic Maddinson',
    'NJ Rimmington': 'Nathan Rimmington',
    'NK Patel': 'Niraj Patel',
    'NL McCullum': 'Nathan McCullum',
    'NLTC Perera': 'Thisara Perera',
    'NM Coulter-Nile': 'Nathan Coulter-Nile',
    'NS Naik': 'Nikhil Naik',
    'NT Ellis': 'Nathan Ellis',
    'NV Ojha': 'Naman Ojha',
    'O Thomas': 'Oshane Thomas',
    'OA Shah': 'Owais Shah',
    'OC McCoy': 'Obed McCoy',
    'OF Smith': 'Odean Smith',
    'P Amarnath': 'Palani Amarnath',
    'P Awana': 'Parvinder Awana',
    'P Chopra': 'Prashant Chopra',
    'P Dogra': 'Paras Dogra',
    'P Dubey': 'Praveen Dubey',
    'P Kumar': 'Praveen Kumar',
    'P Negi': 'Pawan Negi',
    'P Parameswaran': 'Prasanth Parameswaran',
    'P Prasanth': 'Padmanabhan Prasanth',
    'P Ray Barman': 'Prayas Ray Barman',
    'P Sahu': 'Pardeep Sahu',
    'P Simran Singh': 'Prabhsimran Singh',
    'P Suyal': 'Pawan Suyal',
    'PA Patel': 'Parthiv Patel',
    'PA Reddy': 'Akshath Reddy',
    'PBB Rajapaksa': 'Bhanuka Rajapaksa',
    'PC Valthaty': 'Paul Valthaty',
    'PD Collingwood': 'Paul Collingwood',
    'PD Salt': 'Phil Salt',
    'PH Solanki': 'Prashant Solanki',
    'PHKD Mendis': 'Kamindu Mendis',
    'PJ Cummins': 'Pat Cummins',
    'PJ Sangwan': 'Pradeep Sangwan',
    'PK Garg': 'Priyam Garg',
    'PM Sarvesh Kumar': 'Sarvesh Kumar',
    'PN Mankad': 'Prerak Mankad',
    'PP Chawla': 'Piyush Chawla',
    'PP Ojha': 'Pragyan Ojha',
    'PP Shaw': 'Prithvi Shaw',
    'PR Shah': 'Pinal Shah',
    'PSP Handscomb': 'Peter Handscomb',
    'PV Tambe': 'Pravin Tambe',
    'PVD Chameera': 'Dushmantha Chameera',
    'PVSN Raju': 'Venugopal Rao',
    'PWA Mulder': 'Wiaan Mulder',
    'PWH de Silva': 'Wanindu Hasaranga',
    'Q de Kock': 'Quinton de Kock',
    'R Ashwin': 'Ravichandran Ashwin',
    'R Bhatia': 'Rajat Bhatia',
    'R Bishnoi': 'Ravi Bishnoi',
    'R Dhawan': 'Rishi Dhawan',
    'R Dravid': 'Rahul Dravid',
    'R Goyal': 'Ravi Goyal',
    'R McLaren': 'Ryan McLaren',
    'R Minz': 'Robin Minz',
    'R Ninan': 'Ryan Ninan',
    'R Parag': 'Riyan Parag',
    'R Powell': 'Rovman Powell',
    'R Rampaul': 'Ravi Rampaul',
    'R Ravindra': 'Rachin Ravindra',
    'R Sai Kishore': 'Ravisrinivasan Sai Kishore',
    'R Sanjay Yadav': 'Sanjay Yadav',
    'R Sathish': 'Rajagopal Sathish',
    'R Sharma': 'Rahul Sharma',
    'R Shepherd': 'Romario Shepherd',
    'R Shukla': 'Rahul Shukla',
    'R Tewatia': 'Rahul Tewatia',
    'R Vinay Kumar': 'Vinay Kumar',
    'RA Bawa': 'Raj Bawa',
    'RA Jadeja': 'Ravindra Jadeja',
    'RA Shaikh': 'Rahil Shaikh',
    'RA Tripathi': 'Rahul Tripathi',
    'RD Chahar': 'Rahul Chahar',
    'RD Gaikwad': 'Ruturaj Gaikwad',
    'RD Rickelton': 'Ryan Rickelton',
    'RE Levi': 'Richard Levi',
    'RE van der Merwe': 'Roelof van der Merwe',
    'RG More': 'Ronit More',
    'RG Sharma': 'Rohit Sharma',
    'RJ Gleeson': 'Richard Gleeson',
    'RJ Harris': 'Ryan Harris',
    'RJ Peterson': 'Robin Peterson',
    'RJ Quiney': 'Rob Quiney',
    'RJW Topley': 'Reece Topley',
    'RK Bhui': 'Ricky Bhui',
    'RK Singh': 'Rinku Singh',
    'RM Patidar': 'Rajat Patidar',
    'RN ten Doeschate': 'Ryan ten Doeschate',
    'RP Meredith': 'Riley Meredith',
    'RP Singh': 'R. P. Singh',
    'RR Bhatkal': 'Raju Bhatkal',
    'RR Bose': 'Ranadeb Bose',
    'RR Pant': 'Rishabh Pant',
    'RR Powar': 'Ramesh Powar',
    'RR Raje': 'Rohan Raje',
    'RR Rossouw': 'Rilee Rossouw',
    'RR Sarwan': 'Ramnaresh Sarwan',
    'RS Bopara': 'Ravi Bopara',
    'RS Gavaskar': 'Rohan Gavaskar',
    'RS Hangargekar': 'Rajvardhan Hangargekar',
    'RS Sodhi': 'Reetinder Sodhi',
    'RT Ponting': 'Ricky Ponting',
    'RV Gomez': 'Raiphi Gomez',
    'RV Patel': 'Ripal Patel',
    'RV Uthappa': 'Robin Uthappa',
    'RW Price': 'Ray Price',
    'S Anirudha': 'Anirudha Srikkanth',
    'S Aravind': 'Sreenath Aravind',
    'S Badree': 'Samuel Badree',
    'S Badrinath': 'Subramaniam Badrinath',
    'S Chanderpaul': 'Shivnarine Chanderpaul',
    'S Dhawan': 'Shikhar Dhawan',
    'S Dube': 'Shivam Dube',
    'S Gopal': 'Shreyas Gopal',
    'S Joseph': 'Shamar Joseph',
    'S Kaul': 'Siddharth Kaul',
    'S Kaushik': 'Shivil Kaushik',
    'S Ladda': 'Sarabjit Ladda',
    'S Lamichhane': 'Sandeep Lamichhane',
    'S Midhun': 'Sudhesan Midhun',
    'S Nadeem': 'Shahbaz Nadeem',
    'S Narwal': 'Sumit Narwal',
    'S Rana': 'Sachin Rana',
    'S Randiv': 'Suraj Randiv',
    'S Sandeep Warrier': 'Sandeep Warrier',
    'S Sohal': 'Sunny Sohal',
    'S Sreesanth': 'Sreesanth',
    'S Sriram': 'Sridharan Sriram',
    'S Tyagi': 'Sudeep Tyagi',
    'S Vidyut': 'Vidyut Sivaramakrishnan',
    'SA Abbott': 'Sean Abbott',
    'SA Asnodkar': 'Swapnil Asnodkar',
    'SA Yadav': 'Suryakumar Yadav',
    'SB Bangar': 'Sanjay Bangar',
    'SB Dubey': 'Shivam Dubey',
    'SB Jakati': 'Shadab Jakati',
    'SB Joshi': 'Sunil Joshi',
    'SB Styris': 'Scott Styris',
    'SB Wagh': 'Shrikant Wagh',
    'SC Ganguly': 'Sourav Ganguly',
    'SC Kuggeleijn': 'Scott Kuggeleijn',
    'SD Chitnis': 'Siddharth Chitnis',
    'SD Hope': 'Shai Hope',
    'SD Lad': 'Siddhesh Lad',
    'SE Bond': 'Shane Bond',
    'SE Marsh': 'Shaun Marsh',
    'SE Rutherford': 'Sherfane Rutherford',
    'SH Johnson': 'Spencer Johnson',
    'SJ Srivastava': 'Shalabh Srivastava',
    'SK Raina': 'Suresh Raina',
    'SK Rasheed': 'Shaik Rasheed',
    'SK Trivedi': 'Siddharth Trivedi',
    'SK Warne': 'Shane Warne',
    'SL Malinga': 'Lasith Malinga',
    'SM Boland': 'Scott Boland',
    'SM Curran': 'Sam Curran',
    'SM Harwood': 'Shane Harwood',
    'SM Katich': 'Simon Katich',
    'SM Pollock': 'Shaun Pollock',
    'SMSM Senanayake': 'Sachithra Senanayake',
    'SN Khan': 'Sarfaraz Khan',
    'SN Thakur': 'Shardul Thakur',
    'SO Hetmyer': 'Shimron Hetmyer',
    'SP Fleming': 'Stephen Fleming',
    'SP Goswami': 'Shreevats Goswami',
    'SP Jackson': 'Sheldon Jackson',
    'SP Narine': 'Sunil Narine',
    'SPD Smith': 'Steve Smith',
    'SR Tendulkar': 'Sachin Tendulkar',
    'SR Watson': 'Shane Watson',
    'SS Agarwal': 'Shubham Agarwal',
    'SS Cottrell': 'Sheldon Cottrell',
    'SS Iyer': 'Shreyas Iyer',
    'SS Mundhe': 'Shrikant Mundhe',
    'SS Prabhudessai': 'Suyash Prabhudessai',
    'SS Sarkar': 'Soumya Sarkar',
    'SS Shaikh': 'Sufiyan Shaikh',
    'SS Tiwary': 'Saurabh Tiwary',
    'SSB Magala': 'Sisanda Magala',
    'ST Jayasuriya': 'Sanath Jayasuriya',
    'STR Binny': 'Stuart Binny',
    'SV Samson': 'Sanju Samson',
    'SW Billings': 'Sam Billings',
    'SW Tait': 'Shaun Tait',
    'SZ Mulani': 'Shams Mulani',
    'T Banton': 'Tom Banton',
    'T Henderson': 'Tyron Henderson',
    'T Kohler-Cadmore': 'Tom Kohler-Cadmore',
    'T Kohli': 'Taruwar Kohli',
    'T Natarajan': 'T. Natarajan',
    'T Shamsi': 'Tabraiz Shamsi',
    'T Stubbs': 'Tristan Stubbs',
    'T Taibu': 'Tatenda Taibu',
    'T Thushara': 'Thilan Thushara',
    'TA Boult': 'Trent Boult',
    'TD Paine': 'Tim Paine',
    'TG Southee': 'Tim Southee',
    'TH David': 'Tim David',
    'TK Curran': 'Tom Curran',
    'TL Seifert': 'Tim Seifert',
    'TL Suman': 'Tirumalasetti Suman',
    'TM Dilshan': 'Tillakaratne Dilshan',
    'TM Head': 'Travis Head',
    'TM Srivastava': 'Tanmay Srivastava',
    'TP Sudhindra': 'T. P. Sudhindra',
    'TR Birt': 'Travis Birt',
    'TS Mills': 'Tymal Mills',
    'TU Deshpande': 'Tushar Deshpande',
    'U Kaul': 'Uday Kaul',
    'UA Birla': 'Udit Birla',
    'UBT Chand': 'Unmukt Chand',
    'UT Khawaja': 'Usman Khawaja',
    'UT Yadav': 'Umesh Yadav',
    'V Kaverappa': 'Vidwath Kaverappa',
    'V Kohli': 'Virat Kohli',
    'V Nigam': 'Vikas Nigam',
    'V Pratap Singh': 'Vishwa Pratap Singh',
    'V Puthur': 'Vyshak Vijaykumar',
    'V Sehwag': 'Virender Sehwag',
    'V Shankar': 'Vijay Shankar',
    'V Suryavanshi': 'Vaibhav Suryavanshi',
    'V Viyaskanth': 'Vijayakanth Viyaskanth',
    'VG Arora': 'Vaibhav Arora',
    'VH Zol': 'Vijay Zol',
    'VR Aaron': 'Varun Aaron',
    'VR Iyer': 'Venkatesh Iyer',
    'VRV Singh': 'V. R. V. Singh',
    'VS Malik': 'Vikramjeet Malik',
    'VS Yeligati': 'Vinayak Yeligati',
    'VVS Laxman': 'V. V. S. Laxman',
    'VY Mahesh': 'V. Y. Mahesh',
    'W Jaffer': 'Wasim Jaffer',
    "W O'Rourke": "William O'Rourke",
    'WA Mota': 'Wilkin Mota',
    'WD Parnell': 'Wayne Parnell',
    'WG Jacks': 'Will Jacks',
    'WP Saha': 'Wriddhiman Saha',
    'WPUJC Vaas': 'Chaminda Vaas',
    'X Thalaivan Sargunam': 'Xavier Thalaivan Sargunam',
    'XC Bartlett': 'Xavier Bartlett',
    'Y Gnaneswara Rao': 'Yalaka Gnaneswara Rao',
    'Y Nagar': 'Yogesh Nagar',
    'Y Prithvi Raj': 'Yarra Prithvi Raj',
    'Y Venugopal Rao': 'Yalaka Venugopal Rao',
    'YA Abdulla': 'Yusuf Abdulla',
    'YBK Jaiswal': 'Yashasvi Jaiswal',
    'YK Pathan': 'Yusuf Pathan',
    'YS Chahal': 'Yuzvendra Chahal',
    'YV Dhull': 'Yash Dhull',
    'YV Takawale': 'Yogesh Takawale',
    'Z Khan': 'Zaheer Khan'
}

# %%
historical_data['player'] = historical_data['player'].replace(player_mapping)
data['player'] = data['player'].replace(player_mapping)

# %%
historical_data.columns
# Out:
# Index(['match_id', 'player', 'fantasy_points', 'team', 'opponent', 'venue',
#        'toss_decision', 'stage', 'season', 'player_match_number',
#        'last3_avg_points', 'last5_avg_points', 'last10_avg_points',
#        'rolling_strike_rate', 'rolling_wickets', 'opponent_avg_points',
#        'pitch_type', 'venue_avg_points', 'venue_run_factor',
#        'batting_contribution_ratio', 'bowling_contribution_ratio',
#        'player_role', 'last10_std_points', 'player_consistency_index',
#        'form_momentum', 'bat_pos', 'boundary_percentage', 'bat_pos_per_match',
#        'player_role_wicketkeeper', 'match_month', 'team_won_toss',
#        'recent_form', 'venue_form'],
#       dtype='object')

# %%
historical_data
# Out:
#        match_id          player  fantasy_points                 team  \
# 0        548341    Ashish Reddy            58.0      Deccan Chargers
# 1        548346    Ashish Reddy            41.0      Deccan Chargers
# 2        548348    Ashish Reddy            23.0      Deccan Chargers
# 3        548352    Ashish Reddy            28.0      Deccan Chargers
# 4        548356    Ashish Reddy            33.0      Deccan Chargers
# ...         ...             ...             ...                  ...
# 25120   1473478  Zeeshan Ansari            25.0  Sunrisers Hyderabad
# 25121   1473480  Zeeshan Ansari             0.0  Sunrisers Hyderabad
# 25122   1473488  Zeeshan Ansari            23.0  Sunrisers Hyderabad
# 25123   1473492  Zeeshan Ansari             4.0  Sunrisers Hyderabad
# 25124   1473499  Zeeshan Ansari            -2.0  Sunrisers Hyderabad
#
#                           opponent  \
# 0                    Pune Warriors
# 1                   Mumbai Indians
# ...

# %%
colsToDrop =  ['last5_avg_points',
              'last10_avg_points',
              'bat_pos_per_match',
              'match_month',
              'stage'
              ]
historical_data = historical_data.drop(columns = colsToDrop)

# %%
historical_data.columns
# Out:
# Index(['match_id', 'player', 'fantasy_points', 'team', 'opponent', 'venue',
#        'toss_decision', 'season', 'player_match_number', 'last3_avg_points',
#        'rolling_strike_rate', 'rolling_wickets', 'opponent_avg_points',
#        'pitch_type', 'venue_avg_points', 'venue_run_factor',
#        'batting_contribution_ratio', 'bowling_contribution_ratio',
#        'player_role', 'last10_std_points', 'player_consistency_index',
#        'form_momentum', 'bat_pos', 'boundary_percentage',
#        'player_role_wicketkeeper', 'team_won_toss', 'recent_form',
#        'venue_form'],
#       dtype='object')

# %%
from difflib import get_close_matches
unique_player_list_from_df = historical_data['player'].unique()
unique_players = list(unique_player_list_from_df)
print(unique_player_list_from_df)

def map_player_name(name):
    
    match = get_close_matches(name, unique_players, n=1, cutoff=0.5)
    
    if match:
        return match[0]
    else:
        return None
# Out:
# ['Ashish Reddy' 'Ayush Badoni' 'Ajit Chandila' 'Aakash Chopra'
#  'Aniket Choudhary' 'Akila Dananjaya' 'Andrew Flintoff' 'Anshul Kamboj'
#  'Anil Kumble' 'Abhinav Manohar' 'Ayush Mhatre' 'Amit Mishra'
#  'Abhimanyu Mithun' 'Abhinav Mukund' 'Ashish Nehra' 'André Nel'
#  'Anrich Nortje' 'Angkrish Raghuvanshi' 'Anureet Singh' 'Andrew Symonds'
#  'Anshuman Tomar' 'Amit Uniyal' 'Adam Zampa' 'Akshath Bilakhia'
#  'Ankeet Chavan' 'Abhishek Jhunjhunwala' 'Abrar Kazi' 'Arshin Kulkarni'
#  'Ashley Noffke' 'Ajit Agarkar' 'Adrian Barath' 'Ashoke Dinda'
#  'Andrew McDonald' 'AB de Villiers' 'Aiden Blizzard' 'Adam Gilchrist'
#  'Alfonso Thomas' 'Adam Voges' 'Alex Hales' 'Dimitri Mascarenhas'
#  'Angelo Mathews' 'Akshdeep Nath' 'Andre Russell' 'Adam Milne'
#  'Ali Murtaza' 'Amit Paunikar' 'Aaron Finch' 'Akeal Hosein'
#  'Ashton Turner' 'Andrew Tye' 'Aiden Markram' 'Ashok Menaria'
#  'Abhishek Nayar' 'Ajinkya Rahane' 'Aavishkar Salvi' 'Abu Nechim'
# ...

# %%
mapped_players_1 = [map_player_name(p) for p in team1_squad]
mapped_players_2 = [map_player_name(p) for p in team2_squad]

mapped_players_1+mapped_players_2
all_mapped = mapped_players_1 + mapped_players_2

# %%
all_mapped
# Out:
# ['MS Dhoni',
#  'Ravindra Jadeja',
#  'Ruturaj Gaikwad',
#  'Deepak Chahar',
#  'Moeen Ali',
#  'Shivam Dube',
#  'Matheesha Pathirana',
#  'Ajinkya Rahane',
#  'Daryl Mitchell',
#  'Mitchell Santner',
#  'Tushar Deshpande',
#  'Rohit Sharma',
#  'Ishan Kishan',
#  'Suryakumar Yadav',
#  'Hardik Pandya',
#  'Tim David',
#  'Jasprit Bumrah',
#  'Piyush Chawla',
#  'Tilak Varma',
#  'Gerald Coetzee',
#  'Romario Shepherd',
#  'Nehal Wadhera']

# %%
unique_venue_list_from_df = historical_data['venue'].unique()
unique_venues = list(unique_venue_list_from_df)
print(unique_venues)
def map_venue_name(name):
    
    match = get_close_matches(name, unique_venues, n=1, cutoff=0.5)
    
    if match:
        return match[0]
    else:
        return None
print(historical_data['venue'].value_counts())
# Out:
# ['Subrata Roy Sahara Stadium', 'Wankhede Stadium', 'Barabati Stadium', 'MA Chidambaram Stadium', 'M Chinnaswamy Stadium', 'Rajiv Gandhi International Stadium', 'Arun Jaitley Stadium', 'Eden Gardens', 'Maharashtra Cricket Association Stadium', 'Sawai Mansingh Stadium', 'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium', 'Punjab Cricket Association IS Bindra Stadium', 'Brabourne Stadium', 'Dr DY Patil Sports Academy', 'Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium', 'Narendra Modi Stadium', 'Himachal Pradesh Cricket Association Stadium', 'Newlands', "St George's Park", 'Kingsmead', 'New Wanderers Stadium', 'SuperSport Park', 'Vidarbha Cricket Association Stadium, Jamtha', 'Buffalo Park', 'OUTsurance Oval', 'Nehru Stadium', 'Sheikh Zayed Stadium', 'Sharjah Cricket Stadium', 'Dubai International Cricket Stadium', 'Shaheed Veer Narayan Singh International Stadium', 'Saurashtra Cricket Association Stadium', 'Green Park', 'JSCA International Stadium Complex', 'Barsapara Cr
# ...

# %%
from difflib import get_close_matches
mapped_venues = map_venue_name(venue)
mapped_venues
# Out:
# 'Wankhede Stadium'

# %%
players_df = data[
    data['player'].isin(all_mapped)
].copy()
players_df
# Out:
#        match_id          player  fantasy_points  \
# 1557     335994  Ajinkya Rahane            -2.0
# 1558     335997  Ajinkya Rahane             5.0
# 1559     392203  Ajinkya Rahane            11.0
# 1560     392208  Ajinkya Rahane            -2.0
# 1561     392215  Ajinkya Rahane            14.0
# ...         ...             ...             ...
# 23066   1473493     Tilak Varma             7.0
# 23067   1473501     Tilak Varma            30.0
# 23068   1473506     Tilak Varma             1.0
# 23069   1473509     Tilak Varma            45.0
# 23070   1473510     Tilak Varma            58.0
#
#                                                    venue   season  \
# 1557                          Dr DY Patil Sports Academy  2007/08
# 1558                                        Eden Gardens  2007/08
# 1559                                        Buffalo Park     2009
# 1560                               New Wanderers Stadium     2009
# ...

# %%
players_df = (
    players_df
    .sort_values('player_match_number')
    .groupby('player')
    .tail(1)
)
players_df
# Out:
#        match_id               player  fantasy_points  \
# 6141    1473509       Gerald Coetzee             2.0
# 5105    1426306       Daryl Mitchell            20.0
# 16745   1473511     Romario Shepherd            43.0
# 12432   1473510     Mitchell Santner             6.0
# 14364   1473511        Nehal Wadhera            17.0
# 11561   1473504  Matheesha Pathirana            41.0
# 22805   1473503            Tim David             1.0
# 23017   1473500     Tushar Deshpande            33.0
# 23070   1473510          Tilak Varma            58.0
# 12819   1473494            Moeen Ali            29.0
# 17445   1473459      Ruturaj Gaikwad             1.0
# 19174   1473504          Shivam Dube            31.0
# 5251    1473506        Deepak Chahar            12.0
# 7797    1473505         Ishan Kishan            37.0
# 8635    1473510       Jasprit Bumrah            -2.0
# 6876    1473510        Hardik Pandya            63.0
# 19681   1473510     Suryakumar Yadav            62.0
# ...

# %%
players_df['venue'] = venue
players_df
# Out:
#        match_id               player  fantasy_points             venue season  \
# 6141    1473509       Gerald Coetzee             2.0  Wankhede Stadium   2025
# 5105    1426306       Daryl Mitchell            20.0  Wankhede Stadium   2024
# 16745   1473511     Romario Shepherd            43.0  Wankhede Stadium   2025
# 12432   1473510     Mitchell Santner             6.0  Wankhede Stadium   2025
# 14364   1473511        Nehal Wadhera            17.0  Wankhede Stadium   2025
# 11561   1473504  Matheesha Pathirana            41.0  Wankhede Stadium   2025
# 22805   1473503            Tim David             1.0  Wankhede Stadium   2025
# 23017   1473500     Tushar Deshpande            33.0  Wankhede Stadium   2025
# 23070   1473510          Tilak Varma            58.0  Wankhede Stadium   2025
# 12819   1473494            Moeen Ali            29.0  Wankhede Stadium   2025
# 17445   1473459      Ruturaj Gaikwad             1.0  Wankhede Stadium   2025
# ...

# %%
players_df = players_df.drop(columns = ['venue_avg_points','venue_run_factor'])
venue_data = data[data['venue'] == venue][['player','venue_avg_points','venue_run_factor']].drop_duplicates()
venue_data
# Out:
#                  player  venue_avg_points  venue_run_factor
# 1          Ashish Reddy         41.000000          1.035196
# 28         Ayush Badoni         42.000000          1.035196
# 91        Aakash Chopra          1.000000          1.035196
# 96     Aniket Choudhary         25.000000          1.035196
# 99      Akila Dananjaya          0.000000          1.035196
# ...                 ...               ...               ...
# 24628  Yuzvendra Chahal         43.333333          1.035196
# 24810        Yash Dayal         24.250000          1.035196
# 24895      Yuvraj Singh         32.300000          1.035196
# 25017       Zaheer Khan         33.500000          1.035196
# 25119    Zeeshan Ansari         12.000000          1.035196
#
# [477 rows x 3 columns]

# %%
players_df = players_df.merge(venue_data,on = ['player'],how = 'left')
players_df
# Out:
#     match_id               player  fantasy_points             venue season  \
# 0    1473509       Gerald Coetzee             2.0  Wankhede Stadium   2025
# 1    1426306       Daryl Mitchell            20.0  Wankhede Stadium   2024
# 2    1473511     Romario Shepherd            43.0  Wankhede Stadium   2025
# 3    1473510     Mitchell Santner             6.0  Wankhede Stadium   2025
# 4    1473511        Nehal Wadhera            17.0  Wankhede Stadium   2025
# 5    1473504  Matheesha Pathirana            41.0  Wankhede Stadium   2025
# 6    1473503            Tim David             1.0  Wankhede Stadium   2025
# 7    1473500     Tushar Deshpande            33.0  Wankhede Stadium   2025
# 8    1473510          Tilak Varma            58.0  Wankhede Stadium   2025
# 9    1473494            Moeen Ali            29.0  Wankhede Stadium   2025
# 10   1473459      Ruturaj Gaikwad             1.0  Wankhede Stadium   2025
# ...

# %%
pd.set_option("display.max_columns",None)

# %%
players_df
# Out:
#     match_id               player  fantasy_points             venue season  \
# 0    1473509       Gerald Coetzee             2.0  Wankhede Stadium   2025
# 1    1426306       Daryl Mitchell            20.0  Wankhede Stadium   2024
# 2    1473511     Romario Shepherd            43.0  Wankhede Stadium   2025
# 3    1473510     Mitchell Santner             6.0  Wankhede Stadium   2025
# 4    1473511        Nehal Wadhera            17.0  Wankhede Stadium   2025
# 5    1473504  Matheesha Pathirana            41.0  Wankhede Stadium   2025
# 6    1473503            Tim David             1.0  Wankhede Stadium   2025
# 7    1473500     Tushar Deshpande            33.0  Wankhede Stadium   2025
# 8    1473510          Tilak Varma            58.0  Wankhede Stadium   2025
# 9    1473494            Moeen Ali            29.0  Wankhede Stadium   2025
# 10   1473459      Ruturaj Gaikwad             1.0  Wankhede Stadium   2025
# ...

# %%
venue_run_data = historical_data[historical_data['venue'] == venue][['player','venue_run_factor']].drop_duplicates()
venue_run_data
# Out:
#                  player  venue_run_factor
# 1          Ashish Reddy          1.035196
# 28         Ayush Badoni          1.035196
# 91        Aakash Chopra          1.035196
# 96     Aniket Choudhary          1.035196
# 99      Akila Dananjaya          1.035196
# ...                 ...               ...
# 24628  Yuzvendra Chahal          1.035196
# 24810        Yash Dayal          1.035196
# 24895      Yuvraj Singh          1.035196
# 25017       Zaheer Khan          1.035196
# 25119    Zeeshan Ansari          1.035196
#
# [473 rows x 2 columns]

# %%
players_df = players_df.drop(columns = ['venue_run_factor'])
players_df = players_df.merge(venue_run_data,on = ['player'],how = 'left')
players_df
# Out:
#     match_id               player  fantasy_points             venue season  \
# 0    1473509       Gerald Coetzee             2.0  Wankhede Stadium   2025
# 1    1426306       Daryl Mitchell            20.0  Wankhede Stadium   2024
# 2    1473511     Romario Shepherd            43.0  Wankhede Stadium   2025
# 3    1473510     Mitchell Santner             6.0  Wankhede Stadium   2025
# 4    1473511        Nehal Wadhera            17.0  Wankhede Stadium   2025
# 5    1473504  Matheesha Pathirana            41.0  Wankhede Stadium   2025
# 6    1473503            Tim David             1.0  Wankhede Stadium   2025
# 7    1473500     Tushar Deshpande            33.0  Wankhede Stadium   2025
# 8    1473510          Tilak Varma            58.0  Wankhede Stadium   2025
# 9    1473494            Moeen Ali            29.0  Wankhede Stadium   2025
# 10   1473459      Ruturaj Gaikwad             1.0  Wankhede Stadium   2025
# ...

# %%
players_df = players_df.drop(columns = ['venue_form'])
players_df['venue_form'] = players_df['venue_avg_points'] * players_df['recent_form']
players_df
# Out:
#     match_id               player  fantasy_points             venue season  \
# 0    1473509       Gerald Coetzee             2.0  Wankhede Stadium   2025
# 1    1426306       Daryl Mitchell            20.0  Wankhede Stadium   2024
# 2    1473511     Romario Shepherd            43.0  Wankhede Stadium   2025
# 3    1473510     Mitchell Santner             6.0  Wankhede Stadium   2025
# 4    1473511        Nehal Wadhera            17.0  Wankhede Stadium   2025
# 5    1473504  Matheesha Pathirana            41.0  Wankhede Stadium   2025
# 6    1473503            Tim David             1.0  Wankhede Stadium   2025
# 7    1473500     Tushar Deshpande            33.0  Wankhede Stadium   2025
# 8    1473510          Tilak Varma            58.0  Wankhede Stadium   2025
# 9    1473494            Moeen Ali            29.0  Wankhede Stadium   2025
# 10   1473459      Ruturaj Gaikwad             1.0  Wankhede Stadium   2025
# ...

# %%
players_df.columns
# Out:
# Index(['match_id', 'player', 'fantasy_points', 'venue', 'season',
#        'player_match_number', 'last3_avg_points', 'rolling_strike_rate',
#        'rolling_wickets', 'opponent_avg_points', 'batting_contribution_ratio',
#        'bowling_contribution_ratio', 'last10_std_points',
#        'player_consistency_index', 'form_momentum', 'bat_pos',
#        'boundary_percentage', 'player_role_wicketkeeper', 'team_won_toss',
#        'recent_form', 'team_Deccan Chargers', 'team_Delhi Capitals',
#        'team_Gujarat Lions', 'team_Gujarat Titans',
#        'team_Kochi Tuskers Kerala', 'team_Kolkata Knight Riders',
#        'team_Lucknow Super Giants', 'team_Mumbai Indians',
#        'team_Pune Warriors', 'team_Punjab Kings', 'team_Rajasthan Royals',
#        'team_Rising Pune Supergiants', 'team_Royal Challengers Bengaluru',
#        'team_Sunrisers Hyderabad', 'opponent_Deccan Chargers',
#        'opponent_Delhi Capitals', 'opponent_Gujarat Lions',
# ...

# %%
historical_data
# Out:
#        match_id          player  fantasy_points                 team  \
# 0        548341    Ashish Reddy            58.0      Deccan Chargers
# 1        548346    Ashish Reddy            41.0      Deccan Chargers
# 2        548348    Ashish Reddy            23.0      Deccan Chargers
# 3        548352    Ashish Reddy            28.0      Deccan Chargers
# 4        548356    Ashish Reddy            33.0      Deccan Chargers
# ...         ...             ...             ...                  ...
# 25120   1473478  Zeeshan Ansari            25.0  Sunrisers Hyderabad
# 25121   1473480  Zeeshan Ansari             0.0  Sunrisers Hyderabad
# 25122   1473488  Zeeshan Ansari            23.0  Sunrisers Hyderabad
# 25123   1473492  Zeeshan Ansari             4.0  Sunrisers Hyderabad
# 25124   1473499  Zeeshan Ansari            -2.0  Sunrisers Hyderabad
#
#                           opponent  \
# 0                    Pune Warriors
# 1                   Mumbai Indians
# ...

# %%
historical_data['last3_battingcontri'] = historical_data.groupby(['player'])['batting_contribution_ratio'].rolling(3,min_periods = 1).mean().reset_index(level=0, drop=True)

# %%
historical_data
# Out:
#        match_id          player  fantasy_points                 team  \
# 0        548341    Ashish Reddy            58.0      Deccan Chargers
# 1        548346    Ashish Reddy            41.0      Deccan Chargers
# 2        548348    Ashish Reddy            23.0      Deccan Chargers
# 3        548352    Ashish Reddy            28.0      Deccan Chargers
# 4        548356    Ashish Reddy            33.0      Deccan Chargers
# ...         ...             ...             ...                  ...
# 25120   1473478  Zeeshan Ansari            25.0  Sunrisers Hyderabad
# 25121   1473480  Zeeshan Ansari             0.0  Sunrisers Hyderabad
# 25122   1473488  Zeeshan Ansari            23.0  Sunrisers Hyderabad
# 25123   1473492  Zeeshan Ansari             4.0  Sunrisers Hyderabad
# 25124   1473499  Zeeshan Ansari            -2.0  Sunrisers Hyderabad
#
#                           opponent  \
# 0                    Pune Warriors
# 1                   Mumbai Indians
# ...

# %%
historical_data['last3_bowlingcontri'] = historical_data.groupby(['player'])['bowling_contribution_ratio'].rolling(3,min_periods = 1).mean().reset_index(level=0, drop=True)

# %%
historical_data['last3_boundarypercentage'] = historical_data.groupby(['player'])['boundary_percentage'].rolling(3,min_periods = 1).mean().reset_index(level=0, drop=True)
# historical_data.to_csv("/Users/nidhishgupta/Desktop/Dream11_Fantasy Team_Predictor/data/processed/historical_data_final.csv",index = False)
# data.to_csv("/Users/nidhishgupta/Desktop/Dream11_Fantasy Team_Predictor/data/processed/full_req_data_final.csv",index = False)

# %%
ratio_info = historical_data[['player','player_match_number','last3_battingcontri','last3_bowlingcontri','last3_boundarypercentage']]
ratio_df = (
    ratio_info
    .sort_values('player_match_number')
    .groupby('player')
    .tail(1)
)
ratio_df = ratio_df.drop(columns = ['player_match_number'])
ratio_df
# Out:
#                 player  last3_battingcontri  last3_bowlingcontri  \
# 16481       Ravi Goyal             0.000000             0.000000
# 2300      Abdur Razzak             0.250000             0.750000
# 16657     Sanjay Yadav             0.333333             0.666667
# 2248      Abdul Basith             1.000000             0.000000
# 18036     Raju Bhatkal             0.250000             0.750000
# ...                ...                  ...                  ...
# 9771    Dinesh Karthik             1.000000             0.000000
# 13476         MS Dhoni             1.000000             0.000000
# 17196  Ravindra Jadeja             0.214910             0.785090
# 23544      Virat Kohli             1.000000             0.000000
# 17757     Rohit Sharma             1.000000             0.000000
#
#        last3_boundarypercentage
# 16481                  0.000000
# 2300                   0.000000
# 16657                  0.000000
# 2248                   0.000000
# ...

# %%
players_df = players_df.merge(ratio_df,on = ['player'],how = 'left')
players_df
# Out:
#     match_id               player  fantasy_points             venue season  \
# 0    1473509       Gerald Coetzee             2.0  Wankhede Stadium   2025
# 1    1426306       Daryl Mitchell            20.0  Wankhede Stadium   2024
# 2    1473511     Romario Shepherd            43.0  Wankhede Stadium   2025
# 3    1473510     Mitchell Santner             6.0  Wankhede Stadium   2025
# 4    1473511        Nehal Wadhera            17.0  Wankhede Stadium   2025
# 5    1473504  Matheesha Pathirana            41.0  Wankhede Stadium   2025
# 6    1473503            Tim David             1.0  Wankhede Stadium   2025
# 7    1473500     Tushar Deshpande            33.0  Wankhede Stadium   2025
# 8    1473510          Tilak Varma            58.0  Wankhede Stadium   2025
# 9    1473494            Moeen Ali            29.0  Wankhede Stadium   2025
# 10   1473459      Ruturaj Gaikwad             1.0  Wankhede Stadium   2025
# ...

# %%
players_df = players_df.drop(columns = ['batting_contribution_ratio','bowling_contribution_ratio','boundary_percentage'])
players_df = players_df.rename(columns = {"last3_battingcontri":"batting_contribution_ratio","last3_bowlingcontri":"bowling_contribution_ratio",'last3_boundarypercentage':'boundary_percentage'})

# %%
players_df
# Out:
#     match_id               player  fantasy_points             venue season  \
# 0    1473509       Gerald Coetzee             2.0  Wankhede Stadium   2025
# 1    1426306       Daryl Mitchell            20.0  Wankhede Stadium   2024
# 2    1473511     Romario Shepherd            43.0  Wankhede Stadium   2025
# 3    1473510     Mitchell Santner             6.0  Wankhede Stadium   2025
# 4    1473511        Nehal Wadhera            17.0  Wankhede Stadium   2025
# 5    1473504  Matheesha Pathirana            41.0  Wankhede Stadium   2025
# 6    1473503            Tim David             1.0  Wankhede Stadium   2025
# 7    1473500     Tushar Deshpande            33.0  Wankhede Stadium   2025
# 8    1473510          Tilak Varma            58.0  Wankhede Stadium   2025
# 9    1473494            Moeen Ali            29.0  Wankhede Stadium   2025
# 10   1473459      Ruturaj Gaikwad             1.0  Wankhede Stadium   2025
# ...

# %%
historical_data.columns
# Out:
# Index(['match_id', 'player', 'fantasy_points', 'team', 'opponent', 'venue',
#        'toss_decision', 'season', 'player_match_number', 'last3_avg_points',
#        'rolling_strike_rate', 'rolling_wickets', 'opponent_avg_points',
#        'pitch_type', 'venue_avg_points', 'venue_run_factor',
#        'batting_contribution_ratio', 'bowling_contribution_ratio',
#        'player_role', 'last10_std_points', 'player_consistency_index',
#        'form_momentum', 'bat_pos', 'boundary_percentage',
#        'player_role_wicketkeeper', 'team_won_toss', 'recent_form',
#        'venue_form', 'last3_battingcontri', 'last3_bowlingcontri',
#        'last3_boundarypercentage'],
#       dtype='object')

# %%
players_df.columns
# Out:
# Index(['match_id', 'player', 'fantasy_points', 'venue', 'season',
#        'player_match_number', 'last3_avg_points', 'rolling_strike_rate',
#        'rolling_wickets', 'opponent_avg_points', 'last10_std_points',
#        'player_consistency_index', 'form_momentum', 'bat_pos',
#        'player_role_wicketkeeper', 'team_won_toss', 'recent_form',
#        'team_Deccan Chargers', 'team_Delhi Capitals', 'team_Gujarat Lions',
#        'team_Gujarat Titans', 'team_Kochi Tuskers Kerala',
#        'team_Kolkata Knight Riders', 'team_Lucknow Super Giants',
#        'team_Mumbai Indians', 'team_Pune Warriors', 'team_Punjab Kings',
#        'team_Rajasthan Royals', 'team_Rising Pune Supergiants',
#        'team_Royal Challengers Bengaluru', 'team_Sunrisers Hyderabad',
#        'opponent_Deccan Chargers', 'opponent_Delhi Capitals',
#        'opponent_Gujarat Lions', 'opponent_Gujarat Titans',
#        'opponent_Kochi Tuskers Kerala', 'opponent_Kolkata Knight Riders',
# ...

# %%
team_cols = [col for col in players_df.columns if col.startswith('team_')]
opponent_cols = [col for col in players_df.columns if col.startswith('opponent_')]

# %%
team_cols = team_cols[1:]

# %%
opponent_cols = opponent_cols[1:]
opponent_cols
# Out:
# ['opponent_Deccan Chargers',
#  'opponent_Delhi Capitals',
#  'opponent_Gujarat Lions',
#  'opponent_Gujarat Titans',
#  'opponent_Kochi Tuskers Kerala',
#  'opponent_Kolkata Knight Riders',
#  'opponent_Lucknow Super Giants',
#  'opponent_Mumbai Indians',
#  'opponent_Pune Warriors',
#  'opponent_Punjab Kings',
#  'opponent_Rajasthan Royals',
#  'opponent_Rising Pune Supergiants',
#  'opponent_Royal Challengers Bengaluru',
#  'opponent_Sunrisers Hyderabad']

# %%
team_cols
# Out:
# ['team_Deccan Chargers',
#  'team_Delhi Capitals',
#  'team_Gujarat Lions',
#  'team_Gujarat Titans',
#  'team_Kochi Tuskers Kerala',
#  'team_Kolkata Knight Riders',
#  'team_Lucknow Super Giants',
#  'team_Mumbai Indians',
#  'team_Pune Warriors',
#  'team_Punjab Kings',
#  'team_Rajasthan Royals',
#  'team_Rising Pune Supergiants',
#  'team_Royal Challengers Bengaluru',
#  'team_Sunrisers Hyderabad']

# %%
players_df[team_cols] = False
players_df[opponent_cols] = False

# %%
if f"team_{team1}" in team_cols:
    players_df.loc[players_df['player'].isin(mapped_players_1), f"team_{team1}"] = True

if f"team_{team2}" in team_cols:
    players_df.loc[players_df['player'].isin(mapped_players_2), f"team_{team2}"] = True
if f"opponent_{team2}" in opponent_cols:
    players_df.loc[players_df['player'].isin(mapped_players_1), f"opponent_{team2}"] = True

if f"opponent_{team1}" in opponent_cols:
    players_df.loc[players_df['player'].isin(mapped_players_2), f"opponent_{team1}"] = True

# %%
players_df
# Out:
#     match_id               player  fantasy_points             venue season  \
# 0    1473509       Gerald Coetzee             2.0  Wankhede Stadium   2025
# 1    1426306       Daryl Mitchell            20.0  Wankhede Stadium   2024
# 2    1473511     Romario Shepherd            43.0  Wankhede Stadium   2025
# 3    1473510     Mitchell Santner             6.0  Wankhede Stadium   2025
# 4    1473511        Nehal Wadhera            17.0  Wankhede Stadium   2025
# 5    1473504  Matheesha Pathirana            41.0  Wankhede Stadium   2025
# 6    1473503            Tim David             1.0  Wankhede Stadium   2025
# 7    1473500     Tushar Deshpande            33.0  Wankhede Stadium   2025
# 8    1473510          Tilak Varma            58.0  Wankhede Stadium   2025
# 9    1473494            Moeen Ali            29.0  Wankhede Stadium   2025
# 10   1473459      Ruturaj Gaikwad             1.0  Wankhede Stadium   2025
# ...

# %%
opponent_avg_dict = historical_data.groupby(['player','opponent'])['fantasy_points'].mean().to_dict()

# %%
player_avg_dict = (
    historical_data
    .groupby('player')['fantasy_points']
    .mean()
    .to_dict()
)

# %%
opponent_cols = [c for c in players_df.columns if c.startswith('opponent_')]
opponent_cols = opponent_cols[1:]
opponent_cols
# Out:
# ['opponent_Deccan Chargers',
#  'opponent_Delhi Capitals',
#  'opponent_Gujarat Lions',
#  'opponent_Gujarat Titans',
#  'opponent_Kochi Tuskers Kerala',
#  'opponent_Kolkata Knight Riders',
#  'opponent_Lucknow Super Giants',
#  'opponent_Mumbai Indians',
#  'opponent_Pune Warriors',
#  'opponent_Punjab Kings',
#  'opponent_Rajasthan Royals',
#  'opponent_Rising Pune Supergiants',
#  'opponent_Royal Challengers Bengaluru',
#  'opponent_Sunrisers Hyderabad']

# %%
players_df['opponent_temp'] = (
    players_df[opponent_cols]
    .idxmax(axis=1)
    .str.replace('opponent_', '')
)

# %%
players_df
# Out:
#     match_id               player  fantasy_points             venue season  \
# 0    1473509       Gerald Coetzee             2.0  Wankhede Stadium   2025
# 1    1426306       Daryl Mitchell            20.0  Wankhede Stadium   2024
# 2    1473511     Romario Shepherd            43.0  Wankhede Stadium   2025
# 3    1473510     Mitchell Santner             6.0  Wankhede Stadium   2025
# 4    1473511        Nehal Wadhera            17.0  Wankhede Stadium   2025
# 5    1473504  Matheesha Pathirana            41.0  Wankhede Stadium   2025
# 6    1473503            Tim David             1.0  Wankhede Stadium   2025
# 7    1473500     Tushar Deshpande            33.0  Wankhede Stadium   2025
# 8    1473510          Tilak Varma            58.0  Wankhede Stadium   2025
# 9    1473494            Moeen Ali            29.0  Wankhede Stadium   2025
# 10   1473459      Ruturaj Gaikwad             1.0  Wankhede Stadium   2025
# ...

# %%
all_opponents = historical_data['opponent'].unique()
encoded_opponents = [c.replace('opponent_', '') for c in opponent_cols]

dropped_opponent = list(set(all_opponents) - set(encoded_opponents))[0]

mask = players_df[opponent_cols].sum(axis=1) == 0
players_df.loc[mask, 'opponent_temp'] = dropped_opponent

# %%
players_df
# Out:
#     match_id               player  fantasy_points             venue season  \
# 0    1473509       Gerald Coetzee             2.0  Wankhede Stadium   2025
# 1    1426306       Daryl Mitchell            20.0  Wankhede Stadium   2024
# 2    1473511     Romario Shepherd            43.0  Wankhede Stadium   2025
# 3    1473510     Mitchell Santner             6.0  Wankhede Stadium   2025
# 4    1473511        Nehal Wadhera            17.0  Wankhede Stadium   2025
# 5    1473504  Matheesha Pathirana            41.0  Wankhede Stadium   2025
# 6    1473503            Tim David             1.0  Wankhede Stadium   2025
# 7    1473500     Tushar Deshpande            33.0  Wankhede Stadium   2025
# 8    1473510          Tilak Varma            58.0  Wankhede Stadium   2025
# 9    1473494            Moeen Ali            29.0  Wankhede Stadium   2025
# 10   1473459      Ruturaj Gaikwad             1.0  Wankhede Stadium   2025
# ...

# %%
def get_opponent_avg(row):
    key = (row['player'], row['opponent_temp'])
    
    if key in opponent_avg_dict:
        return opponent_avg_dict[key]
    else:
        return player_avg_dict.get(row['player'], 0)
    
players_df = players_df.drop(columns = ['opponent_avg_points'])
players_df['opponent_avg_points'] = players_df.apply(get_opponent_avg, axis=1)

# %%
players_df
# Out:
#     match_id               player  fantasy_points             venue season  \
# 0    1473509       Gerald Coetzee             2.0  Wankhede Stadium   2025
# 1    1426306       Daryl Mitchell            20.0  Wankhede Stadium   2024
# 2    1473511     Romario Shepherd            43.0  Wankhede Stadium   2025
# 3    1473510     Mitchell Santner             6.0  Wankhede Stadium   2025
# 4    1473511        Nehal Wadhera            17.0  Wankhede Stadium   2025
# 5    1473504  Matheesha Pathirana            41.0  Wankhede Stadium   2025
# 6    1473503            Tim David             1.0  Wankhede Stadium   2025
# 7    1473500     Tushar Deshpande            33.0  Wankhede Stadium   2025
# 8    1473510          Tilak Varma            58.0  Wankhede Stadium   2025
# 9    1473494            Moeen Ali            29.0  Wankhede Stadium   2025
# 10   1473459      Ruturaj Gaikwad             1.0  Wankhede Stadium   2025
# ...

# %%
# X_pred = players_df.drop(columns=['fantasy_points','player','venue','player_match_number','match_id','season','player_role_batsman','player_role_bowler','opponent_temp'])

# players_df['predicted_points'] = model.predict(X_pred)

# %%
# players_df.sort_values(by= ['predicted_points'],ascending= False).head(11)

# %%
players_df = players_df.drop(columns = ['opponent_temp'])

# %%
players_df
# Out:
#     match_id               player  fantasy_points             venue season  \
# 0    1473509       Gerald Coetzee             2.0  Wankhede Stadium   2025
# 1    1426306       Daryl Mitchell            20.0  Wankhede Stadium   2024
# 2    1473511     Romario Shepherd            43.0  Wankhede Stadium   2025
# 3    1473510     Mitchell Santner             6.0  Wankhede Stadium   2025
# 4    1473511        Nehal Wadhera            17.0  Wankhede Stadium   2025
# 5    1473504  Matheesha Pathirana            41.0  Wankhede Stadium   2025
# 6    1473503            Tim David             1.0  Wankhede Stadium   2025
# 7    1473500     Tushar Deshpande            33.0  Wankhede Stadium   2025
# 8    1473510          Tilak Varma            58.0  Wankhede Stadium   2025
# 9    1473494            Moeen Ali            29.0  Wankhede Stadium   2025
# 10   1473459      Ruturaj Gaikwad             1.0  Wankhede Stadium   2025
# ...

# %%
venue
# Out:
# 'Wankhede Stadium'

# %%
pitch_info = historical_data[historical_data['venue'] == venue]['pitch_type'].mode()[0]
pitch_info
# Out:
# 'batting_friendly'

# %%
pitch_cols = [
    'pitch_type_batting_friendly',
    'pitch_type_pace_friendly',
    'pitch_type_spin_friendly'
]

players_df[pitch_cols] = False

# %%
if pitch_info == 'batting_friendly':
    players_df['pitch_type_batting_friendly'] = True
elif pitch_info == 'pace_friendly':
    players_df['pitch_type_pace_friendly'] = True
elif pitch_info == 'spin_friendly':
    players_df['pitch_type_spin_friendly'] = True

# %%
players_df
# Out:
#     match_id               player  fantasy_points             venue season  \
# 0    1473509       Gerald Coetzee             2.0  Wankhede Stadium   2025
# 1    1426306       Daryl Mitchell            20.0  Wankhede Stadium   2024
# 2    1473511     Romario Shepherd            43.0  Wankhede Stadium   2025
# 3    1473510     Mitchell Santner             6.0  Wankhede Stadium   2025
# 4    1473511        Nehal Wadhera            17.0  Wankhede Stadium   2025
# 5    1473504  Matheesha Pathirana            41.0  Wankhede Stadium   2025
# 6    1473503            Tim David             1.0  Wankhede Stadium   2025
# 7    1473500     Tushar Deshpande            33.0  Wankhede Stadium   2025
# 8    1473510          Tilak Varma            58.0  Wankhede Stadium   2025
# 9    1473494            Moeen Ali            29.0  Wankhede Stadium   2025
# 10   1473459      Ruturaj Gaikwad             1.0  Wankhede Stadium   2025
# ...

# %%
X_pred = players_df.drop(columns=['fantasy_points','player','venue','player_match_number','match_id','season','player_role_batsman','player_role_bowler'])

players_df['predicted_points'] = model.predict(X_pred)

# %%
players_df.sort_values(by= ['predicted_points'],ascending= False)
# Out:
#     match_id               player  fantasy_points             venue season  \
# 13   1473505         Ishan Kishan            37.0  Wankhede Stadium   2025
# 19   1473500             MS Dhoni            18.0  Wankhede Stadium   2025
# 10   1473459      Ruturaj Gaikwad             1.0  Wankhede Stadium   2025
# 20   1473504      Ravindra Jadeja            78.0  Wankhede Stadium   2025
# 18   1426305        Piyush Chawla            87.0  Wankhede Stadium   2024
# 16   1473510     Suryakumar Yadav            62.0  Wankhede Stadium   2025
# 1    1426306       Daryl Mitchell            20.0  Wankhede Stadium   2024
# 11   1473504          Shivam Dube            31.0  Wankhede Stadium   2025
# 6    1473503            Tim David             1.0  Wankhede Stadium   2025
# 21   1473510         Rohit Sharma             9.0  Wankhede Stadium   2025
# 17   1473505       Ajinkya Rahane            18.0  Wankhede Stadium   2025
# ...

# %%
historical_data
# Out:
#        match_id          player  fantasy_points                 team  \
# 0        548341    Ashish Reddy            58.0      Deccan Chargers
# 1        548346    Ashish Reddy            41.0      Deccan Chargers
# 2        548348    Ashish Reddy            23.0      Deccan Chargers
# 3        548352    Ashish Reddy            28.0      Deccan Chargers
# 4        548356    Ashish Reddy            33.0      Deccan Chargers
# ...         ...             ...             ...                  ...
# 25120   1473478  Zeeshan Ansari            25.0  Sunrisers Hyderabad
# 25121   1473480  Zeeshan Ansari             0.0  Sunrisers Hyderabad
# 25122   1473488  Zeeshan Ansari            23.0  Sunrisers Hyderabad
# 25123   1473492  Zeeshan Ansari             4.0  Sunrisers Hyderabad
# 25124   1473499  Zeeshan Ansari            -2.0  Sunrisers Hyderabad
#
#                           opponent  \
# 0                    Pune Warriors
# 1                   Mumbai Indians
# ...

# %%
team_map = {}

for player in mapped_players_1:
    team_map[player] = team1

for player in mapped_players_2:
    team_map[player] = team2
players_df['team'] = players_df['player'].map(team_map)

# %%
team_map
# Out:
# {'MS Dhoni': 'Chennai Super Kings',
#  'Ravindra Jadeja': 'Chennai Super Kings',
#  'Ruturaj Gaikwad': 'Chennai Super Kings',
#  'Deepak Chahar': 'Chennai Super Kings',
#  'Moeen Ali': 'Chennai Super Kings',
#  'Shivam Dube': 'Chennai Super Kings',
#  'Matheesha Pathirana': 'Chennai Super Kings',
#  'Ajinkya Rahane': 'Chennai Super Kings',
#  'Daryl Mitchell': 'Chennai Super Kings',
#  'Mitchell Santner': 'Chennai Super Kings',
#  'Tushar Deshpande': 'Chennai Super Kings',
#  'Rohit Sharma': 'Mumbai Indians',
#  'Ishan Kishan': 'Mumbai Indians',
#  'Suryakumar Yadav': 'Mumbai Indians',
#  'Hardik Pandya': 'Mumbai Indians',
#  'Tim David': 'Mumbai Indians',
#  'Jasprit Bumrah': 'Mumbai Indians',
#  'Piyush Chawla': 'Mumbai Indians',
#  'Tilak Varma': 'Mumbai Indians',
#  'Gerald Coetzee': 'Mumbai Indians',
#  'Romario Shepherd': 'Mumbai Indians',
#  'Nehal Wadhera': 'Mumbai Indians'}

# %%
players_df
# Out:
#     match_id               player  fantasy_points             venue season  \
# 0    1473509       Gerald Coetzee             2.0  Wankhede Stadium   2025
# 1    1426306       Daryl Mitchell            20.0  Wankhede Stadium   2024
# 2    1473511     Romario Shepherd            43.0  Wankhede Stadium   2025
# 3    1473510     Mitchell Santner             6.0  Wankhede Stadium   2025
# 4    1473511        Nehal Wadhera            17.0  Wankhede Stadium   2025
# 5    1473504  Matheesha Pathirana            41.0  Wankhede Stadium   2025
# 6    1473503            Tim David             1.0  Wankhede Stadium   2025
# 7    1473500     Tushar Deshpande            33.0  Wankhede Stadium   2025
# 8    1473510          Tilak Varma            58.0  Wankhede Stadium   2025
# 9    1473494            Moeen Ali            29.0  Wankhede Stadium   2025
# 10   1473459      Ruturaj Gaikwad             1.0  Wankhede Stadium   2025
# ...

# %%
role_map = (
    historical_data
    .groupby('player')['player_role']
    .agg(lambda x: x.mode()[0])
)

# %%
players_df['role'] = players_df['player'].map(role_map)

# %%
players_df
# Out:
#     match_id               player  fantasy_points             venue season  \
# 0    1473509       Gerald Coetzee             2.0  Wankhede Stadium   2025
# 1    1426306       Daryl Mitchell            20.0  Wankhede Stadium   2024
# 2    1473511     Romario Shepherd            43.0  Wankhede Stadium   2025
# 3    1473510     Mitchell Santner             6.0  Wankhede Stadium   2025
# 4    1473511        Nehal Wadhera            17.0  Wankhede Stadium   2025
# 5    1473504  Matheesha Pathirana            41.0  Wankhede Stadium   2025
# 6    1473503            Tim David             1.0  Wankhede Stadium   2025
# 7    1473500     Tushar Deshpande            33.0  Wankhede Stadium   2025
# 8    1473510          Tilak Varma            58.0  Wankhede Stadium   2025
# 9    1473494            Moeen Ali            29.0  Wankhede Stadium   2025
# 10   1473459      Ruturaj Gaikwad             1.0  Wankhede Stadium   2025
# ...

# %%
player_stats = historical_data.groupby('player').agg({
    'batting_contribution_ratio': 'mean',
    'bowling_contribution_ratio': 'mean'
}).reset_index()

# %%
def assign_role(row):
    bat = row['batting_contribution_ratio']
    bowl = row['bowling_contribution_ratio']
    
    # All-rounder: contributes in BOTH
    if bat > 0.25 and bowl > 0.25:
        return 'AR'
    
    # Pure batsman
    elif bat >= bowl:
        return 'BAT'
    
    # Pure bowler
    else:
        return 'BOWL'

# %%
player_stats
# Out:
#                player  batting_contribution_ratio  bowling_contribution_ratio
# 0      AB de Villiers                    1.000000                    0.000000
# 1       Aakash Chopra                    1.000000                    0.000000
# 2         Aaron Finch                    0.985597                    0.014403
# 3     Aavishkar Salvi                    0.000000                    0.857143
# 4        Abdul Basith                    1.000000                    0.000000
# ..                ...                         ...                         ...
# 752      Yusuf Pathan                    0.849483                    0.138247
# 753      Yuvraj Singh                    0.829905                    0.139560
# 754  Yuzvendra Chahal                   -0.002716                    0.904450
# 755       Zaheer Khan                    0.075727                    0.782859
# 756    Zeeshan Ansari                    0.000000                    0.800000
#
# [757 rows x 3 columns]

# %%
player_stats['role'] = player_stats.apply(assign_role, axis=1)

# %%
player_stats.head(50)
# Out:
#                    player  batting_contribution_ratio  \
# 0          AB de Villiers                    1.000000
# 1           Aakash Chopra                    1.000000
# 2             Aaron Finch                    0.985597
# 3         Aavishkar Salvi                    0.000000
# 4            Abdul Basith                    1.000000
# 5             Abdul Samad                    0.972791
# 6            Abdur Razzak                    0.250000
# 7        Abhimanyu Mithun                    0.212625
# 8         Abhinav Manohar                    1.000000
# 9          Abhinav Mukund                    1.000000
# 10  Abhishek Jhunjhunwala                    0.804639
# 11         Abhishek Nayar                    0.824043
# 12          Abhishek Raut                    0.944444
# 13        Abhishek Sharma                    0.866969
# 14          Abishek Porel                    1.000000
# 15             Abrar Kazi                    0.000000
# ...

# %%
players_df = players_df.drop(columns = ['role'])

# %%
role_map = dict(zip(player_stats['player'], player_stats['role']))
players_df['role'] = players_df['player'].map(role_map).fillna('BAT')

# %%
players_df
# Out:
#     match_id               player  fantasy_points             venue season  \
# 0    1473509       Gerald Coetzee             2.0  Wankhede Stadium   2025
# 1    1426306       Daryl Mitchell            20.0  Wankhede Stadium   2024
# 2    1473511     Romario Shepherd            43.0  Wankhede Stadium   2025
# 3    1473510     Mitchell Santner             6.0  Wankhede Stadium   2025
# 4    1473511        Nehal Wadhera            17.0  Wankhede Stadium   2025
# 5    1473504  Matheesha Pathirana            41.0  Wankhede Stadium   2025
# 6    1473503            Tim David             1.0  Wankhede Stadium   2025
# 7    1473500     Tushar Deshpande            33.0  Wankhede Stadium   2025
# 8    1473510          Tilak Varma            58.0  Wankhede Stadium   2025
# 9    1473494            Moeen Ali            29.0  Wankhede Stadium   2025
# 10   1473459      Ruturaj Gaikwad             1.0  Wankhede Stadium   2025
# ...

# %%
role_constraints = {
    'WK': (1, 4),
    'BAT': (3, 6),
    'AR': (1, 4),
    'BOWL': (3, 6)
}

MAX_PLAYERS = 11
MAX_PER_TEAM = 7

# %%
players_df = players_df.sort_values(by='predicted_points', ascending=False)

# %%
players_df
# Out:
#     match_id               player  fantasy_points             venue season  \
# 13   1473505         Ishan Kishan            37.0  Wankhede Stadium   2025
# 19   1473500             MS Dhoni            18.0  Wankhede Stadium   2025
# 10   1473459      Ruturaj Gaikwad             1.0  Wankhede Stadium   2025
# 20   1473504      Ravindra Jadeja            78.0  Wankhede Stadium   2025
# 18   1426305        Piyush Chawla            87.0  Wankhede Stadium   2024
# 16   1473510     Suryakumar Yadav            62.0  Wankhede Stadium   2025
# 1    1426306       Daryl Mitchell            20.0  Wankhede Stadium   2024
# 11   1473504          Shivam Dube            31.0  Wankhede Stadium   2025
# 6    1473503            Tim David             1.0  Wankhede Stadium   2025
# 21   1473510         Rohit Sharma             9.0  Wankhede Stadium   2025
# 17   1473505       Ajinkya Rahane            18.0  Wankhede Stadium   2025
# ...

# %%
selected = []

for role, (min_req, _) in role_constraints.items():
    role_players = players_df[players_df['role'] == role].head(min_req)
    selected.append(role_players)

selected_df = pd.concat(selected)

# %%
selected_df
# Out:
#     match_id           player  fantasy_points             venue season  \
# 13   1473505     Ishan Kishan            37.0  Wankhede Stadium   2025
# 19   1473500         MS Dhoni            18.0  Wankhede Stadium   2025
# 10   1473459  Ruturaj Gaikwad             1.0  Wankhede Stadium   2025
# 20   1473504  Ravindra Jadeja            78.0  Wankhede Stadium   2025
# 18   1426305    Piyush Chawla            87.0  Wankhede Stadium   2024
# 12   1473506    Deepak Chahar            12.0  Wankhede Stadium   2025
# 0    1473509   Gerald Coetzee             2.0  Wankhede Stadium   2025
#
#     player_match_number  last3_avg_points  rolling_strike_rate  \
# 13                  114         70.000000           110.343137
# 19                  241         25.000000           129.222222
# 10                   70         34.000000            94.405594
# 20                  247         56.000000           129.261438
# 18                  194         57.666667            60.000000
# ...

# %%
# historical_data[historical_data['season'] >= 2022]

# %%
historical_data['season'] = historical_data['season'].str[:4].astype(int)
historical_data['season'].unique()
# Out:
# array([2012, 2013, 2015, 2016, 2022, 2023, 2024, 2025, 2007, 2009, 2017,
#        2018, 2011, 2014, 2019, 2020, 2021])

# %%
# historical_data[(historical_data['season'] >= 2022) & (historical_data['team'] == 'Mumbai Indians')].tail(50)

# %%
# pd.set_option("display.max_rows",None)

# %%
# historical_data[(historical_data['season'] >= 2022) & (historical_data['team'] == 'Mumbai Indians')]
# historical_data

# %%
historical_data['player'].unique()
# Out:
# array(['Ashish Reddy', 'Ayush Badoni', 'Ajit Chandila', 'Aakash Chopra',
#        'Aniket Choudhary', 'Akila Dananjaya', 'Andrew Flintoff',
#        'Anshul Kamboj', 'Anil Kumble', 'Abhinav Manohar', 'Ayush Mhatre',
#        'Amit Mishra', 'Abhimanyu Mithun', 'Abhinav Mukund',
#        'Ashish Nehra', 'André Nel', 'Anrich Nortje',
#        'Angkrish Raghuvanshi', 'Anureet Singh', 'Andrew Symonds',
#        'Anshuman Tomar', 'Amit Uniyal', 'Adam Zampa', 'Akshath Bilakhia',
#        'Ankeet Chavan', 'Abhishek Jhunjhunwala', 'Abrar Kazi',
#        'Arshin Kulkarni', 'Ashley Noffke', 'Ajit Agarkar',
#        'Adrian Barath', 'Ashoke Dinda', 'Andrew McDonald',
#        'AB de Villiers', 'Aiden Blizzard', 'Adam Gilchrist',
#        'Alfonso Thomas', 'Adam Voges', 'Alex Hales',
#        'Dimitri Mascarenhas', 'Angelo Mathews', 'Akshdeep Nath',
#        'Andre Russell', 'Adam Milne', 'Ali Murtaza', 'Amit Paunikar',
#        'Aaron Finch', 'Akeal Hosein', 'Ashton Turner', 'Andrew Tye',
# ...

# %%
player_mapping = {
    'A Ashish Reddy': 'Ashish Reddy',
    'A Badoni': 'Ayush Badoni',
    'A Chandila': 'Ajit Chandila',
    'A Chopra': 'Aakash Chopra',
    'A Choudhary': 'Aniket Choudhary',
    'A Dananjaya': 'Akila Dananjaya',
    'A Flintoff': 'Andrew Flintoff',
    'A Kamboj': 'Anshul Kamboj',
    'A Kumble': 'Anil Kumble',
    'A Manohar': 'Abhinav Manohar',
    'A Mhatre': 'Ayush Mhatre',
    'A Mishra': 'Amit Mishra',
    'A Mithun': 'Abhimanyu Mithun',
    'A Mukund': 'Abhinav Mukund',
    'A Nehra': 'Ashish Nehra',
    'A Nel': 'André Nel',
    'A Nortje': 'Anrich Nortje',
    'A Raghuvanshi': 'Angkrish Raghuvanshi',
    'A Singh': 'Anureet Singh',
    'A Symonds': 'Andrew Symonds',
    'A Tomar': 'Anshuman Tomar',
    'A Uniyal': 'Amit Uniyal',
    'A Zampa': 'Adam Zampa',
    'AA Bilakhia': 'Akshath Bilakhia',
    'AA Chavan': 'Ankeet Chavan',
    'AA Jhunjhunwala': 'Abhishek Jhunjhunwala',
    'AA Kazi': 'Abrar Kazi',
    'AA Kulkarni': 'Arshin Kulkarni',
    'AA Noffke': 'Ashley Noffke',
    'AB Agarkar': 'Ajit Agarkar',
    'AB Barath': 'Adrian Barath',
    'AB Dinda': 'Ashoke Dinda',
    'AB McDonald': 'Andrew McDonald',
    'AB de Villiers': 'AB de Villiers',
    'AC Blizzard': 'Aiden Blizzard',
    'AC Gilchrist': 'Adam Gilchrist',
    'AC Thomas': 'Alfonso Thomas',
    'AC Voges': 'Adam Voges',
    'AD Hales': 'Alex Hales',
    'AD Mascarenhas': 'Dimitri Mascarenhas',
    'AD Mathews': 'Angelo Mathews',
    'AD Nath': 'Akshdeep Nath',
    'AD Russell': 'Andre Russell',
    'AF Milne': 'Adam Milne',
    'AG Murtaza': 'Ali Murtaza',
    'AG Paunikar': 'Amit Paunikar',
    'AJ Finch': 'Aaron Finch',
    'AJ Hosein': 'Akeal Hosein',
    'AJ Turner': 'Ashton Turner',
    'AJ Tye': 'Andrew Tye',
    'AK Markram': 'Aiden Markram',
    'AL Menaria': 'Ashok Menaria',
    'AM Nayar': 'Abhishek Nayar',
    'AM Rahane': 'Ajinkya Rahane',
    'AM Salvi': 'Aavishkar Salvi',
    'AN Ahmed': 'Abu Nechim',
    'AN Ghosh': 'Arindam Ghosh',
    'AP Dole': 'Aditya Dole',
    'AP Majumdar': 'Anustup Majumdar',
    'AP Tare': 'Aditya Tare',
    'AR Bawne': 'Ankit Bawne',
    'AR Patel': 'Axar Patel',
    'AS Joseph': 'Alzarri Joseph',
    'AS Rajpoot': 'Ankit Rajpoot',
    'AS Raut': 'Abhishek Raut',
    'AS Roy': 'Anukul Roy',
    'AS Yadav': 'Suryakumar Yadav',
    'AT Carey': 'Alex Carey',
    'AT Rayudu': 'Ambati Rayudu',
    'AU Rashid': 'Adil Rashid',
    'AUK Pathan': 'Asad Pathan',
    'B Akhil': 'Balachandra Akhil',
    'B Chipli': 'Bharat Chipli',
    'B Geeves': 'Brett Geeves',
    'B Indrajith': 'Baba Indrajith',
    'B Kumar': 'Bhuvaneshwar Kumar',
    'B Laughlin': 'Ben Laughlin',
    'B Lee': 'Brett Lee',
    'B Sai Sudharsan': 'Sai Sudharsan',
    'B Stanlake': 'Billy Stanlake',
    'B Sumanth': 'Bodanapu Sumanth',
    'BA Bhatt': 'Bhargav Bhatt',
    'BA Stokes': 'Ben Stokes',
    'BAW Mendis': 'Ajantha Mendis',
    'BB McCullum': 'Brendon McCullum',
    'BB Samantray': 'Biplab Samantray',
    'BB Sran': 'Barinder Sran',
    'BCJ Cutting': 'Ben Cutting',
    'BE Hendricks': 'Beuran Hendricks',
    'BJ Haddin': 'Brad Haddin',
    'BJ Hodge': 'Brad Hodge',
    'BJ Rohrer': 'Ben Rohrer',
    'BKG Mendis': 'Jeevan Mendis',
    'BMAJ Mendis': 'Jeevan Mendis',
    'BR Dunk': 'Ben Dunk',
    'BR Sharath': 'Barafe Sharath',
    'BW Hilfenhaus': 'Ben Hilfenhaus',
    'C Bosch': 'Corbin Bosch',
    'C Ganapathy': 'Chandrasekar Ganapathy',
    'C Green': 'Cameron Green',
    'C Madan': 'Chandan Madan',
    'C Munro': 'Colin Munro',
    'C Nanda': 'Chetan Nanda',
    'C Sakariya': 'Chetan Sakariya',
    'C de Grandhomme': 'Colin de Grandhomme',
    'CA Ingram': 'Colin Ingram',
    'CA Lynn': 'Chris Lynn',
    'CA Pujara': 'Cheteshwar Pujara',
    'CH Gayle': 'Chris Gayle',
    'CH Morris': 'Chris Morris',
    'CJ Anderson': 'Corey Anderson',
    'CJ Dala': 'Junior Dala',
    'CJ Ferguson': 'Callum Ferguson',
    'CJ Green': 'Chris Green',
    'CJ Jordan': 'Chris Jordan',
    'CJ McKay': 'Clint McKay',
    'CK Kapugedera': 'Chamara Kapugedera',
    'CK Langeveldt': 'Charl Langeveldt',
    'CL White': 'Cameron White',
    'CM Gautam': 'C. M. Gautam',
    'CR Brathwaite': 'Carlos Brathwaite',
    'CR Woakes': 'Chris Woakes',
    'CRD Fernando': 'Dilhara Fernando',
    'CV Varun': 'Varun Chakravarthy',
    'D Brevis': 'Dewald Brevis',
    'D Ferreira': 'Donovan Ferreira',
    'D Jansen': 'Duan Jansen',
    'D Kalyankrishna': 'Doddapaneni Kalyankrishna',
    'D Padikkal': 'Devdutt Padikkal',
    'D Pretorius': 'Dwaine Pretorius',
    'D Salunkhe': 'Dinesh Salunkhe',
    'D Wiese': 'David Wiese',
    'D du Preez': 'Dillon du Preez',
    'DA Miller': 'David Miller',
    'DA Warner': 'David Warner',
    'DAJ Bracewell': 'Doug Bracewell',
    'DB Das': 'Debabrata Das',
    'DB Ravi Teja': 'Dwaraka Ravi Teja',
    'DE Bollinger': 'Doug Bollinger',
    'DG Nalkande': 'Darshan Nalkande',
    'DH Yagnik': 'Dishant Yagnik',
    'DJ Bravo': 'Dwayne Bravo',
    'DJ Harris': 'Daniel Harris',
    'DJ Hooda': 'Deepak Hooda',
    'DJ Hussey': 'David Hussey',
    'DJ Jacobs': 'Davy Jacobs',
    'DJ Malan': 'Dawid Malan',
    'DJ Mitchell': 'Daryl Mitchell',
    'DJ Muthuswami': 'Domnic Muthuswami',
    'DJ Thornely': 'Dominic Thornely',
    'DJ Willey': 'David Willey',
    'DJG Sammy': 'Darren Sammy',
    'DJM Short': "D'Arcy Short",
    'DL Chahar': 'Deepak Chahar',
    'DL Vettori': 'Daniel Vettori',
    'DM Bravo': 'Darren Bravo',
    'DNT Zoysa': 'Nuwan Zoysa',
    'DP Conway': 'Devon Conway',
    'DP Nannes': 'Dirk Nannes',
    'DP Vijaykumar': 'Doddapaneni Vijaykumar',
    'DPMD Jayawardene': 'Mahela Jayawardene',
    'DR Martyn': 'Damien Martyn',
    'DR Sams': 'Daniel Sams',
    'DR Shorey': 'Dhruv Shorey',
    'DR Smith': 'Dwayne Smith',
    'DS Kulkarni': 'Dhawal Kulkarni',
    'DS Lehmann': 'Darren Lehmann',
    'DS Rathi': 'Dhruv Rathi',
    'DT Christian': 'Dan Christian',
    'DT Patil': 'Dinesh Patil',
    'DW Steyn': 'Dale Steyn',
    'E Lewis': 'Evin Lewis',
    'E Malinga': 'Lasith Malinga',
    'EJG Morgan': 'Eoin Morgan',
    'ER Dwivedi': 'Eklavya Dwivedi',
    'F Behardien': 'Farhaan Behardien',
    'F du Plessis': 'Faf du Plessis',
    'FA Allen': 'Fabian Allen',
    'FH Edwards': 'Fidel Edwards',
    'FY Fazal': 'Faiz Fazal',
    'G Coetzee': 'Gerald Coetzee',
    'G Gambhir': 'Gautam Gambhir',
    'GB Hogg': 'Brad Hogg',
    'GC Smith': 'Graeme Smith',
    'GC Viljoen': 'Hardus Viljoen',
    'GD McGrath': 'Glenn McGrath',
    'GD Phillips': 'Glenn Phillips',
    'GH Vihari': 'Hanuma Vihari',
    'GHS Garton': 'George Garton',
    'GJ Bailey': 'George Bailey',
    'GJ Maxwell': 'Glenn Maxwell',
    'GR Napier': 'Graham Napier',
    'GS Sandhu': 'Gurinder Sandhu',
    'H Das': 'Halhadar Das',
    'H Klaasen': 'Heinrich Klaasen',
    'H Sharma': 'Himanshu Sharma',
    'HC Brook': 'Harry Brook',
    'HE van der Dussen': 'Rassie van der Dussen',
    'HF Gurney': 'Harry Gurney',
    'HH Gibbs': 'Herschelle Gibbs',
    'HH Pandya': 'Hardik Pandya',
    'HM Amla': 'Hashim Amla',
    'HR Shokeen': 'Hrithik Shokeen',
    'HV Patel': 'Harshal Patel',
    'I Malhotra': 'Ishan Malhotra',
    'I Sharma': 'Ishant Sharma',
    'I Udana': 'Isuru Udana',
    'IC Pandey': 'Ishwar Pandey',
    'IC Porel': 'Ishan Porel',
    'IK Pathan': 'Irfan Pathan',
    'IR Jaggi': 'Ishank Jaggi',
    'IS Sodhi': 'Ish Sodhi',
    'J Arunkumar': 'Jagadeesh Arunkumar',
    'J Botha': 'Johan Botha',
    'J Fraser-McGurk': 'Jake Fraser-McGurk',
    'J Little': 'Joshua Little',
    'J Overton': 'Jamie Overton',
    'J Suchith': 'Jagadeesha Suchith',
    'J Syed Mohammad': 'Jamaluddin Syed Mohammad',
    'J Theron': 'Juan Theron',
    'J Yadav': 'Jayant Yadav',
    'JA Morkel': 'Albie Morkel',
    'JA Richardson': 'Jhye Richardson',
    'JC Archer': 'Jofra Archer',
    'JC Buttler': 'Jos Buttler',
    'JD Ryder': 'Jesse Ryder',
    'JD Unadkat': 'Jaydev Unadkat',
    'JDP Oram': 'Jacob Oram',
    'JDS Neesham': 'Jimmy Neesham',
    'JE Root': 'Joe Root',
    'JE Taylor': 'Jerome Taylor',
    'JEC Franklin': 'James Franklin',
    'JG Bethell': 'Jacob Bethell',
    'JH Kallis': 'Jacques Kallis',
    'JJ Bumrah': 'Jasprit Bumrah',
    'JJ Roy': 'Jason Roy',
    'JJ van der Wath': 'Johan van der Wath',
    'JL Denly': 'Joe Denly',
    'JL Pattinson': 'James Pattinson',
    'JM Bairstow': 'Jonny Bairstow',
    'JM Kemp': 'Justin Kemp',
    'JM Sharma': 'Jitesh Sharma',
    'JO Holder': 'Jason Holder',
    'JP Behrendorff': 'Jason Behrendorff',
    'JP Duminy': 'JP Duminy',
    'JP Faulkner': 'James Faulkner',
    'JP Inglis': 'Josh Inglis',
    'JPR Scantlebury-Searles': 'Javon Searles',
    'JR Hazlewood': 'Josh Hazlewood',
    'JR Hopes': 'James Hopes',
    'JR Philippe': 'Josh Philippe',
    'JW Hastings': 'John Hastings',
    'K Goel': 'Karan Goel',
    'K Gowtham': 'Krishnappa Gowtham',
    'K Kartikeya': 'Kumar Kartikeya',
    'K Khejroliya': 'Kulwant Khejroliya',
    'K Rabada': 'Kagiso Rabada',
    'K Santokie': 'Krishmar Santokie',
    'K Upadhyay': 'Krishnakumar Upadhyay',
    'K Yadav': 'Kuldeep Yadav',
    'KA Jamieson': 'Kyle Jamieson',
    'KA Maharaj': 'Keshav Maharaj',
    'KA Pollard': 'Kieron Pollard',
    'KAJ Roach': 'Kemar Roach',
    'KB Arun Karthik': 'Arun Karthik',
    'KC Cariappa': 'K. C. Cariappa',
    'KC Sangakkara': 'Kumar Sangakkara',
    'KD Karthik': 'Dinesh Karthik',
    'KH Pandya': 'Krunal Pandya',
    'KJ Abbott': 'Kyle Abbott',
    'KK Ahmed': 'Khaleel Ahmed',
    'KK Cooper': 'Kevon Cooper',
    'KK Nair': 'Karun Nair',
    'KL Nagarkoti': 'Kamlesh Nagarkoti',
    'KL Rahul': 'KL Rahul',
    'KM Asif': 'KM Asif',
    'KM Jadhav': 'Kedar Jadhav',
    'KMA Paul': 'Keemo Paul',
    'KMDN Kulasekara': 'Nuwan Kulasekara',
    'KP Appanna': 'Kotarangada Appanna',
    'KP Pietersen': 'Kevin Pietersen',
    'KR Mayers': 'Kyle Mayers',
    'KR Sen': 'Kuldeep Sen',
    'KS Bharat': 'Srikar Bharat',
    'KS Rathore': 'Kunal Singh Rathore',
    'KS Sharma': 'Karn Sharma',
    'KS Williamson': 'Kane Williamson',
    'KT Maphaka': 'Kwena Maphaka',
    'KV Sharma': 'Karn Sharma',
    'KW Richardson': 'Kane Richardson',
    'L Ablish': 'Love Ablish',
    'L Balaji': 'Lakshmipathy Balaji',
    'L Ngidi': 'Lungi Ngidi',
    'L Ronchi': 'Luke Ronchi',
    'L Wood': 'Luke Wood',
    'LA Carseldine': 'Lee Carseldine',
    'LA Pomersbach': 'Luke Pomersbach',
    'LB Williams': 'Lizaad Williams',
    'LE Plunkett': 'Liam Plunkett',
    'LH Ferguson': 'Lockie Ferguson',
    'LI Meriwala': 'Lukman Meriwala',
    'LJ Wright': 'Luke Wright',
    'LMP Simmons': 'Lendl Simmons',
    'LPC Silva': 'Chamara Silva',
    'LR Shukla': 'Laxmi Ratan Shukla',
    'LRPL Taylor': 'Ross Taylor',
    'LS Livingstone': 'Liam Livingstone',
    'M Ashwin': 'Murugan Ashwin',
    'M Jansen': 'Marco Jansen',
    'M Kaif': 'Mohammad Kaif',
    'M Kartik': 'Murali Kartik',
    'M Klinger': 'Michael Klinger',
    'M Manhas': 'Mithun Manhas',
    'M Markande': 'Mayank Markande',
    'M Morkel': 'Morne Morkel',
    'M Muralitharan': 'Muttiah Muralitharan',
    'M Ntini': 'Makhaya Ntini',
    'M Pathirana': 'Matheesha Pathirana',
    'M Prasidh Krishna': 'Prasidh Krishna',
    'M Rawat': 'Mahesh Rawat',
    'M Shahrukh Khan': 'Shahrukh Khan',
    'M Siddharth': 'Manimaran Siddharth',
    'M Theekshana': 'Maheesh Theekshana',
    'M Tiwari': 'Manoj Tiwary',
    'M Vijay': 'Murali Vijay',
    'M Vohra': 'Manan Vohra',
    'M de Lange': 'Marchant de Lange',
    'MA Agarwal': 'Mayank Agarwal',
    'MA Khote': 'Musavir Khote',
    'MA Starc': 'Mitchell Starc',
    'MA Wood': 'Mark Wood',
    'MB Parmar': 'Mohnish Parmar',
    'MC Henriques': 'Moises Henriques',
    'MC Juneja': 'Manpreet Juneja',
    'MD Mishra': 'Mohnish Mishra',
    'MD Shanaka': 'Dasun Shanaka',
    'MDKJ Perera': 'Kusal Perera',
    'MEK Hussey': 'Michael Hussey',
    'MF Maharoof': 'Farveez Maharoof',
    'MG Bracewell': 'Michael Bracewell',
    'MG Johnson': 'Mitchell Johnson',
    'MG Neser': 'Michael Neser',
    'MJ Clarke': 'Michael Clarke',
    'MJ Guptill': 'Martin Guptill',
    'MJ Henry': 'Matt Henry',
    'MJ Lumb': 'Michael Lumb',
    'MJ McClenaghan': 'Mitchell McClenaghan',
    'MJ Owen': 'Mitchell Owen',
    'MJ Santner': 'Mitchell Santner',
    'MJ Suthar': 'Manav Suthar',
    'MK Lomror': 'Mahipal Lomror',
    'MK Pandey': 'Manish Pandey',
    'MK Tiwary': 'Manoj Tiwary',
    'ML Hayden': 'Matthew Hayden',
    'MM Ali': 'Moeen Ali',
    'MM Patel': 'Munaf Patel',
    'MM Sharma': 'Mohit Sharma',
    'MN Samuels': 'Marlon Samuels',
    'MN van Wyk': 'Morne van Wyk',
    'MP Breetzke': 'Matthew Breetzke',
    'MP Stoinis': 'Marcus Stoinis',
    'MP Yadav': 'Mayank Yadav',
    'MR Marsh': 'Mitchell Marsh',
    'MS Bhandage': 'Manoj Bhandage',
    'MS Bisla': 'Manvinder Bisla',
    'MS Dhoni': 'MS Dhoni',
    'MS Gony': 'Manpreet Gony',
    'MS Wade': 'Matthew Wade',
    'MV Boucher': 'Mark Boucher',
    'MW Short': 'Matthew Short',
    'N Burger': 'Nandre Burger',
    'N Jagadeesan': 'Narayan Jagadeesan',
    'N Pooran': 'Nicholas Pooran',
    'N Rana': 'Nitish Rana',
    'N Saini': 'Navdeep Saini',
    'N Thushara': 'Nuwan Thushara',
    'N Wadhera': 'Nehal Wadhera',
    'NA Saini': 'Navdeep Saini',
    'NB Singh': 'Nikhil Singh',
    'ND Doshi': 'Nayan Doshi',
    'NJ Maddinson': 'Nic Maddinson',
    'NJ Rimmington': 'Nathan Rimmington',
    'NK Patel': 'Niraj Patel',
    'NL McCullum': 'Nathan McCullum',
    'NLTC Perera': 'Thisara Perera',
    'NM Coulter-Nile': 'Nathan Coulter-Nile',
    'NS Naik': 'Nikhil Naik',
    'NT Ellis': 'Nathan Ellis',
    'NV Ojha': 'Naman Ojha',
    'O Thomas': 'Oshane Thomas',
    'OA Shah': 'Owais Shah',
    'OC McCoy': 'Obed McCoy',
    'OF Smith': 'Odean Smith',
    'P Amarnath': 'Palani Amarnath',
    'P Awana': 'Parvinder Awana',
    'P Chopra': 'Prashant Chopra',
    'P Dogra': 'Paras Dogra',
    'P Dubey': 'Praveen Dubey',
    'P Kumar': 'Praveen Kumar',
    'P Negi': 'Pawan Negi',
    'P Parameswaran': 'Prasanth Parameswaran',
    'P Prasanth': 'Padmanabhan Prasanth',
    'P Ray Barman': 'Prayas Ray Barman',
    'P Sahu': 'Pardeep Sahu',
    'P Simran Singh': 'Prabhsimran Singh',
    'P Suyal': 'Pawan Suyal',
    'PA Patel': 'Parthiv Patel',
    'PA Reddy': 'Akshath Reddy',
    'PBB Rajapaksa': 'Bhanuka Rajapaksa',
    'PC Valthaty': 'Paul Valthaty',
    'PD Collingwood': 'Paul Collingwood',
    'PD Salt': 'Phil Salt',
    'PH Solanki': 'Prashant Solanki',
    'PHKD Mendis': 'Kamindu Mendis',
    'PJ Cummins': 'Pat Cummins',
    'PJ Sangwan': 'Pradeep Sangwan',
    'PK Garg': 'Priyam Garg',
    'PM Sarvesh Kumar': 'Sarvesh Kumar',
    'PN Mankad': 'Prerak Mankad',
    'PP Chawla': 'Piyush Chawla',
    'PP Ojha': 'Pragyan Ojha',
    'PP Shaw': 'Prithvi Shaw',
    'PR Shah': 'Pinal Shah',
    'PSP Handscomb': 'Peter Handscomb',
    'PV Tambe': 'Pravin Tambe',
    'PVD Chameera': 'Dushmantha Chameera',
    'PVSN Raju': 'Venugopal Rao',
    'PWA Mulder': 'Wiaan Mulder',
    'PWH de Silva': 'Wanindu Hasaranga',
    'Q de Kock': 'Quinton de Kock',
    'R Ashwin': 'Ravichandran Ashwin',
    'R Bhatia': 'Rajat Bhatia',
    'R Bishnoi': 'Ravi Bishnoi',
    'R Dhawan': 'Rishi Dhawan',
    'R Dravid': 'Rahul Dravid',
    'R Goyal': 'Ravi Goyal',
    'R McLaren': 'Ryan McLaren',
    'R Minz': 'Robin Minz',
    'R Ninan': 'Ryan Ninan',
    'R Parag': 'Riyan Parag',
    'R Powell': 'Rovman Powell',
    'R Rampaul': 'Ravi Rampaul',
    'R Ravindra': 'Rachin Ravindra',
    'R Sai Kishore': 'Ravisrinivasan Sai Kishore',
    'R Sanjay Yadav': 'Sanjay Yadav',
    'R Sathish': 'Rajagopal Sathish',
    'R Sharma': 'Rahul Sharma',
    'R Shepherd': 'Romario Shepherd',
    'R Shukla': 'Rahul Shukla',
    'R Tewatia': 'Rahul Tewatia',
    'R Vinay Kumar': 'Vinay Kumar',
    'RA Bawa': 'Raj Bawa',
    'RA Jadeja': 'Ravindra Jadeja',
    'RA Shaikh': 'Rahil Shaikh',
    'RA Tripathi': 'Rahul Tripathi',
    'RD Chahar': 'Rahul Chahar',
    'RD Gaikwad': 'Ruturaj Gaikwad',
    'RD Rickelton': 'Ryan Rickelton',
    'RE Levi': 'Richard Levi',
    'RE van der Merwe': 'Roelof van der Merwe',
    'RG More': 'Ronit More',
    'RG Sharma': 'Rohit Sharma',
    'RJ Gleeson': 'Richard Gleeson',
    'RJ Harris': 'Ryan Harris',
    'RJ Peterson': 'Robin Peterson',
    'RJ Quiney': 'Rob Quiney',
    'RJW Topley': 'Reece Topley',
    'RK Bhui': 'Ricky Bhui',
    'RK Singh': 'Rinku Singh',
    'RM Patidar': 'Rajat Patidar',
    'RN ten Doeschate': 'Ryan ten Doeschate',
    'RP Meredith': 'Riley Meredith',
    'RP Singh': 'R. P. Singh',
    'RR Bhatkal': 'Raju Bhatkal',
    'RR Bose': 'Ranadeb Bose',
    'RR Pant': 'Rishabh Pant',
    'RR Powar': 'Ramesh Powar',
    'RR Raje': 'Rohan Raje',
    'RR Rossouw': 'Rilee Rossouw',
    'RR Sarwan': 'Ramnaresh Sarwan',
    'RS Bopara': 'Ravi Bopara',
    'RS Gavaskar': 'Rohan Gavaskar',
    'RS Hangargekar': 'Rajvardhan Hangargekar',
    'RS Sodhi': 'Reetinder Sodhi',
    'RT Ponting': 'Ricky Ponting',
    'RV Gomez': 'Raiphi Gomez',
    'RV Patel': 'Ripal Patel',
    'RV Uthappa': 'Robin Uthappa',
    'RW Price': 'Ray Price',
    'S Anirudha': 'Anirudha Srikkanth',
    'S Aravind': 'Sreenath Aravind',
    'S Badree': 'Samuel Badree',
    'S Badrinath': 'Subramaniam Badrinath',
    'S Chanderpaul': 'Shivnarine Chanderpaul',
    'S Dhawan': 'Shikhar Dhawan',
    'S Dube': 'Shivam Dube',
    'S Gopal': 'Shreyas Gopal',
    'S Joseph': 'Shamar Joseph',
    'S Kaul': 'Siddharth Kaul',
    'S Kaushik': 'Shivil Kaushik',
    'S Ladda': 'Sarabjit Ladda',
    'S Lamichhane': 'Sandeep Lamichhane',
    'S Midhun': 'Sudhesan Midhun',
    'S Nadeem': 'Shahbaz Nadeem',
    'S Narwal': 'Sumit Narwal',
    'S Rana': 'Sachin Rana',
    'S Randiv': 'Suraj Randiv',
    'S Sandeep Warrier': 'Sandeep Warrier',
    'S Sohal': 'Sunny Sohal',
    'S Sreesanth': 'Sreesanth',
    'S Sriram': 'Sridharan Sriram',
    'S Tyagi': 'Sudeep Tyagi',
    'S Vidyut': 'Vidyut Sivaramakrishnan',
    'SA Abbott': 'Sean Abbott',
    'SA Asnodkar': 'Swapnil Asnodkar',
    'SA Yadav': 'Suryakumar Yadav',
    'SB Bangar': 'Sanjay Bangar',
    'SB Dubey': 'Shivam Dubey',
    'SB Jakati': 'Shadab Jakati',
    'SB Joshi': 'Sunil Joshi',
    'SB Styris': 'Scott Styris',
    'SB Wagh': 'Shrikant Wagh',
    'SC Ganguly': 'Sourav Ganguly',
    'SC Kuggeleijn': 'Scott Kuggeleijn',
    'SD Chitnis': 'Siddharth Chitnis',
    'SD Hope': 'Shai Hope',
    'SD Lad': 'Siddhesh Lad',
    'SE Bond': 'Shane Bond',
    'SE Marsh': 'Shaun Marsh',
    'SE Rutherford': 'Sherfane Rutherford',
    'SH Johnson': 'Spencer Johnson',
    'SJ Srivastava': 'Shalabh Srivastava',
    'SK Raina': 'Suresh Raina',
    'SK Rasheed': 'Shaik Rasheed',
    'SK Trivedi': 'Siddharth Trivedi',
    'SK Warne': 'Shane Warne',
    'SL Malinga': 'Lasith Malinga',
    'SM Boland': 'Scott Boland',
    'SM Curran': 'Sam Curran',
    'SM Harwood': 'Shane Harwood',
    'SM Katich': 'Simon Katich',
    'SM Pollock': 'Shaun Pollock',
    'SMSM Senanayake': 'Sachithra Senanayake',
    'SN Khan': 'Sarfaraz Khan',
    'SN Thakur': 'Shardul Thakur',
    'SO Hetmyer': 'Shimron Hetmyer',
    'SP Fleming': 'Stephen Fleming',
    'SP Goswami': 'Shreevats Goswami',
    'SP Jackson': 'Sheldon Jackson',
    'SP Narine': 'Sunil Narine',
    'SPD Smith': 'Steve Smith',
    'SR Tendulkar': 'Sachin Tendulkar',
    'SR Watson': 'Shane Watson',
    'SS Agarwal': 'Shubham Agarwal',
    'SS Cottrell': 'Sheldon Cottrell',
    'SS Iyer': 'Shreyas Iyer',
    'SS Mundhe': 'Shrikant Mundhe',
    'SS Prabhudessai': 'Suyash Prabhudessai',
    'SS Sarkar': 'Soumya Sarkar',
    'SS Shaikh': 'Sufiyan Shaikh',
    'SS Tiwary': 'Saurabh Tiwary',
    'SSB Magala': 'Sisanda Magala',
    'ST Jayasuriya': 'Sanath Jayasuriya',
    'STR Binny': 'Stuart Binny',
    'SV Samson': 'Sanju Samson',
    'SW Billings': 'Sam Billings',
    'SW Tait': 'Shaun Tait',
    'SZ Mulani': 'Shams Mulani',
    'T Banton': 'Tom Banton',
    'T Henderson': 'Tyron Henderson',
    'T Kohler-Cadmore': 'Tom Kohler-Cadmore',
    'T Kohli': 'Taruwar Kohli',
    'T Natarajan': 'T. Natarajan',
    'T Shamsi': 'Tabraiz Shamsi',
    'T Stubbs': 'Tristan Stubbs',
    'T Taibu': 'Tatenda Taibu',
    'T Thushara': 'Thilan Thushara',
    'TA Boult': 'Trent Boult',
    'TD Paine': 'Tim Paine',
    'TG Southee': 'Tim Southee',
    'TH David': 'Tim David',
    'TK Curran': 'Tom Curran',
    'TL Seifert': 'Tim Seifert',
    'TL Suman': 'Tirumalasetti Suman',
    'TM Dilshan': 'Tillakaratne Dilshan',
    'TM Head': 'Travis Head',
    'TM Srivastava': 'Tanmay Srivastava',
    'TP Sudhindra': 'T. P. Sudhindra',
    'TR Birt': 'Travis Birt',
    'TS Mills': 'Tymal Mills',
    'TU Deshpande': 'Tushar Deshpande',
    'U Kaul': 'Uday Kaul',
    'UA Birla': 'Udit Birla',
    'UBT Chand': 'Unmukt Chand',
    'UT Khawaja': 'Usman Khawaja',
    'UT Yadav': 'Umesh Yadav',
    'V Kaverappa': 'Vidwath Kaverappa',
    'V Kohli': 'Virat Kohli',
    'V Nigam': 'Vikas Nigam',
    'V Pratap Singh': 'Vishwa Pratap Singh',
    'V Puthur': 'Vyshak Vijaykumar',
    'V Sehwag': 'Virender Sehwag',
    'V Shankar': 'Vijay Shankar',
    'V Suryavanshi': 'Vaibhav Suryavanshi',
    'V Viyaskanth': 'Vijayakanth Viyaskanth',
    'VG Arora': 'Vaibhav Arora',
    'VH Zol': 'Vijay Zol',
    'VR Aaron': 'Varun Aaron',
    'VR Iyer': 'Venkatesh Iyer',
    'VRV Singh': 'V. R. V. Singh',
    'VS Malik': 'Vikramjeet Malik',
    'VS Yeligati': 'Vinayak Yeligati',
    'VVS Laxman': 'V. V. S. Laxman',
    'VY Mahesh': 'V. Y. Mahesh',
    'W Jaffer': 'Wasim Jaffer',
    "W O'Rourke": "William O'Rourke",
    'WA Mota': 'Wilkin Mota',
    'WD Parnell': 'Wayne Parnell',
    'WG Jacks': 'Will Jacks',
    'WP Saha': 'Wriddhiman Saha',
    'WPUJC Vaas': 'Chaminda Vaas',
    'X Thalaivan Sargunam': 'Xavier Thalaivan Sargunam',
    'XC Bartlett': 'Xavier Bartlett',
    'Y Gnaneswara Rao': 'Yalaka Gnaneswara Rao',
    'Y Nagar': 'Yogesh Nagar',
    'Y Prithvi Raj': 'Yarra Prithvi Raj',
    'Y Venugopal Rao': 'Yalaka Venugopal Rao',
    'YA Abdulla': 'Yusuf Abdulla',
    'YBK Jaiswal': 'Yashasvi Jaiswal',
    'YK Pathan': 'Yusuf Pathan',
    'YS Chahal': 'Yuzvendra Chahal',
    'YV Dhull': 'Yash Dhull',
    'YV Takawale': 'Yogesh Takawale',
    'Z Khan': 'Zaheer Khan'
}

# %%
# def build_dream11_team(players_df):
#     team = []
    
#     role_count = {'wk': 0, 'BAT': 0, 'BOWL': 0, 'AR': 0}
#     team_count = {}

#     for _, row in players_df.iterrows():
#         player = row['player']
#         role = row['role']
#         team_name = row['team']
#         is_wk = row['player_role_wicketkeeper']
        
#         # Determine role
#         if is_wk:
#             player_role = 'wk'
#         else:
#             player_role = role
        
#         # Check team limit (max 7 players from a team)
#         if team_name not in team_count:
#             team_count[team_name] = 0
#         if team_count[team_name] >= 7:
#             continue
        
#         # Check role limits
#         if player_role == 'wk' and role_count['wk'] >= 4:
#             continue
#         if player_role == 'BAT' and role_count['BAT'] >= 6:
#             continue
#         if player_role == 'BOWL' and role_count['BOWL'] >= 6:
#             continue
#         if player_role == 'AR' and role_count['AR'] >= 4:
#             continue
        
#         # Add player
#         team.append(player)
#         role_count[player_role] += 1
#         team_count[team_name] += 1
        
#         # Stop if 11 players selected
#         if len(team) == 11:
#             break

#     return team, role_count, team_count

# %%
# def validate_and_fix(team, players_df):
#     # Convert to df
#     selected = players_df[players_df['player'].isin(team)]
    
#     def count_roles(df):
#         wk = df['player_role_wicketkeeper'].sum()
#         bat = len(df[(df['role'] == 'BAT') & (~df['player_role_wicketkeeper'])])
#         bowl = len(df[df['role'] == 'BOWL'])
#         ar = len(df[df['role'] == 'AR'])
#         return wk, bat, bowl, ar

#     wk, bat, bowl, ar = count_roles(selected)
    
#     # Add missing WK if needed
#     if wk == 0:
#         wk_candidates = players_df[
#             (players_df['player_role_wicketkeeper']) &
#             (~players_df['player'].isin(team))
#         ]
#         if not wk_candidates.empty:
#             team[-1] = wk_candidates.iloc[0]['player']
    
#     return team

# %%
# def choose_captains(team, players_df):
#     selected = players_df[players_df['player'].isin(team)]
#     selected = selected.sort_values(by='predicted_points', ascending=False)
    
#     captain = selected.iloc[0]['player']
#     vice_captain = selected.iloc[1]['player']
    
#     return captain, vice_captain

# %%
players_df = players_df.sort_values(by='predicted_points', ascending=False).reset_index(drop=True)

# %%
# team, role_count, team_count = build_dream11_team(players_df)

# %%
# team
# Out:
# ['Ishan Kishan',
#  'MS Dhoni',
#  'Ruturaj Gaikwad',
#  'Ravindra Jadeja',
#  'Piyush Chawla',
#  'Suryakumar Yadav',
#  'Daryl Mitchell',
#  'Shivam Dube',
#  'Tim David',
#  'Rohit Sharma',
#  'Romario Shepherd']

# %%
# role_count
# Out:
# {'wk': 2, 'BAT': 6, 'BOWL': 1, 'AR': 2}

# %%
# team_count
# Out:
# {'Mumbai Indians': 6, 'Chennai Super Kings': 5}

# %%
# team = validate_and_fix(team, players_df)

# %%
# team
# Out:
# ['Ishan Kishan',
#  'MS Dhoni',
#  'Ruturaj Gaikwad',
#  'Ravindra Jadeja',
#  'Piyush Chawla',
#  'Suryakumar Yadav',
#  'Daryl Mitchell',
#  'Shivam Dube',
#  'Tim David',
#  'Rohit Sharma',
#  'Romario Shepherd']

# %%
# captain, vice_captain = choose_captains(team, players_df)

# %%
# print("🏏 Final Team:")
# print(team)

# print("\n📊 Role Distribution:")
# print(role_count)

# print("\n🏢 Team Distribution:")
# print(team_count)

# print("\n👑 Captain:", captain)
# print("🤝 Vice-Captain:", vice_captain)
# Out:
# 🏏 Final Team:
# ['Ishan Kishan', 'MS Dhoni', 'Ruturaj Gaikwad', 'Ravindra Jadeja', 'Piyush Chawla', 'Suryakumar Yadav', 'Daryl Mitchell', 'Shivam Dube', 'Tim David', 'Rohit Sharma', 'Romario Shepherd']
#
# 📊 Role Distribution:
# {'wk': 2, 'BAT': 6, 'BOWL': 1, 'AR': 2}
#
# 🏢 Team Distribution:
# {'Mumbai Indians': 6, 'Chennai Super Kings': 5}
#
# 👑 Captain: Ishan Kishan
# 🤝 Vice-Captain: MS Dhoni

# %%
def get_role(row):
    if row['player_role_wicketkeeper']:
        return 'WK'
    return row['role'].upper()

players_df['final_role'] = players_df.apply(get_role, axis=1)

# %%
def build_valid_team(players_df):
    team = []
    team_count = {}
    
    role_constraints = {
        'WK': (1, 4),
        'BAT': (3, 6),
        'AR': (1, 4),
        'BOWL': (3, 6)
    }

    role_count = {r: 0 for r in role_constraints}

    # ✅ Step 1: Fill minimum requirements
    for role, (min_req, max_req) in role_constraints.items():
        candidates = players_df[
            (players_df['final_role'] == role) &
            (~players_df['player'].isin(team))
        ]
        
        for _, row in candidates.iterrows():
            if role_count[role] >= min_req:
                break
                
            team_name = row['team']
            
            if team_count.get(team_name, 0) >= 7:
                continue
            
            team.append(row['player'])
            role_count[role] += 1
            team_count[team_name] = team_count.get(team_name, 0) + 1

    # ✅ Step 2: Fill remaining slots (best players)
    for _, row in players_df.iterrows():
        if len(team) >= 11:
            break
            
        player = row['player']
        role = row['final_role']
        team_name = row['team']
        
        if player in team:
            continue
        
        # Team constraint
        if team_count.get(team_name, 0) >= 7:
            continue
        
        # Role max constraint
        if role_count[role] >= role_constraints[role][1]:
            continue
        
        team.append(player)
        role_count[role] += 1
        team_count[team_name] = team_count.get(team_name, 0) + 1

    return team, role_count, team_count

# %%
team, role_count, team_count = build_valid_team(players_df)
captain, vice_captain = choose_captains(team, players_df)

# %%
print("Team size:", len(team))
print("Role count:", role_count)
print("Team count:", team_count)
# Out:
# Team size: 11
# Role count: {'WK': 2, 'BAT': 5, 'AR': 1, 'BOWL': 3}
# Team count: {'Mumbai Indians': 5, 'Chennai Super Kings': 6}

# %%
print("🏏 Final Team:")
print(team)

print("\n📊 Role Distribution:")
print(role_count)

print("\n🏢 Team Distribution:")
print(team_count)

print("\n👑 Captain:", captain)
print("🤝 Vice-Captain:", vice_captain)
# Out:
# 🏏 Final Team:
# ['Ishan Kishan', 'Ruturaj Gaikwad', 'Suryakumar Yadav', 'Daryl Mitchell', 'Ravindra Jadeja', 'Piyush Chawla', 'Deepak Chahar', 'Gerald Coetzee', 'MS Dhoni', 'Shivam Dube', 'Tim David']
#
# 📊 Role Distribution:
# {'WK': 2, 'BAT': 5, 'AR': 1, 'BOWL': 3}
#
# 🏢 Team Distribution:
# {'Mumbai Indians': 5, 'Chennai Super Kings': 6}
#
# 👑 Captain: Ishan Kishan
# 🤝 Vice-Captain: MS Dhoni
